# %% [markdown]
# # Fisher's tests
#
# Unfortunately I started this notebook thinking I would only test a few gene lists, so wasn't too worried about repeating code. However, I ended up testing more gene lists than expected and so there is a lot of repeated code here. I should have made this notebook cleaner with no repeated code.

# %% [markdown]
# # Do the features overlap with COSMIC?

# %%
# read in COSMIC
import pandas as pd
cosmic = pd.read_csv('Census_allFri Oct  8 15_32_31 2021.csv')
cosmic['ensembl_id'] = cosmic['Synonyms'].str.extract(r'(ENSG\d{11})') # extract ensembl id
cosmic
# Out:
#     Gene Symbol                                               Name  \
# 0          A1CF                     APOBEC1 complementation factor
# 1          ABI1                                   abl-interactor 1
# 2          ABL1  v-abl Abelson murine leukemia viral oncogene h...
# 3          ABL2     c-abl oncogene 2, non-receptor tyrosine kinase
# 4         ACKR3                      atypical chemokine receptor 3
# ..          ...                                                ...
# 718      ZNF429                            zinc finger protein 429
# 719      ZNF479                            zinc finger protein 479
# 720      ZNF521                            zinc finger protein 521
# 721       ZNRF3                             zinc and ring finger 3
# 722       ZRSR2  zinc finger (CCCH type), RNA-binding motif and...
#
#      Entrez GeneId        Genome Location  Tier Hallmark  Chr Band Somatic  \
# 0          29974.0   10:50799421-50885675     2      NaN     11.23     yes
# 1          10006.0   10:26746593-26860935     1      Yes     12.10     yes
# 2             25.0  9:130713946-130885683     1      Yes     34.12     yes
# 3             27.0  1:179099327-179229601     1      NaN     25.20     yes
# 4          57007.0  2:236569641-236582358     1      Yes     37.30     yes
# ..             ...                    ...   ...      ...       ...     ...
# 718       353088.0   19:21505564-21538078     2      NaN     12.00     yes
# 719        90827.0    7:57119614-57139864     2      NaN     11.20     yes
# 720        25925.0   18:25061926-25352152     1      NaN     11.20     yes
# 721        84133.0   22:28883592-29057487     2      NaN     12.10     yes
# 722         8233.0    X:15790472-15823260     1      Yes     22.20     yes
#
#     Germline                              Tumour Types(Somatic)  ...  \
# 0        NaN                                           melanoma  ...
# 1        NaN                                                AML  ...
# 2        NaN                                    CML, ALL, T-ALL  ...
# 3        NaN                                                AML  ...
# 4        NaN                                             lipoma  ...
# ..       ...                                                ...  ...
# 718      NaN                                                GBM  ...
# 719      NaN  lung cancer, bladder carcinoma, prostate carci...  ...
# 720      NaN                                                ALL  ...
# 721      NaN  colorectal cancer, adrenocortical carcinoma, g...  ...
# 722      NaN                                           MDS, CLL  ...
#
#     Cancer Syndrome Tissue Type Molecular Genetics    Role in Cancer  \
# 0               NaN           E                NaN          oncogene
# 1               NaN           L                Dom       TSG, fusion
# 2               NaN           L                Dom  oncogene, fusion
# 3               NaN           L                Dom  oncogene, fusion
# 4               NaN           M                Dom  oncogene, fusion
# ..              ...         ...                ...               ...
# 718             NaN           O                NaN               NaN
# 719             NaN           E                NaN               NaN
# 720             NaN           L                Dom  oncogene, fusion
# 721             NaN           E                NaN               TSG
# 722             NaN           L                Rec               TSG
#
#     Mutation Types Translocation Partner Other Germline Mut Other Syndrome  \
# 0              Mis                   NaN                NaN            NaN
# 1                T                 KMT2A                NaN            NaN
# 2           T, Mis     BCR, ETV6, NUP214                NaN            NaN
# 3                T                  ETV6                NaN            NaN
# 4                T                 HMGA2                NaN            NaN
# ..             ...                   ...                ...            ...
# 718            Mis                   NaN                NaN            NaN
# 719            Mis                   NaN                NaN            NaN
# 720              T                  PAX5                NaN            NaN
# 721      N, F, Mis                   NaN                NaN            NaN
# 722      F, S, Mis                   NaN                NaN            NaN
#
#                                               Synonyms       ensembl_id
# 0    29974,A1CF,ACF,ACF64,ACF65,APOBEC1CF,ASP,ENSG0...  ENSG00000148584
# 1    10006,ABI-1,ABI1,E3B1,ENSG00000136754.17,Q8IZP...  ENSG00000136754
# 2    25,ABL,ABL1,ENSG00000097007.17,JTK7,P00519,c-A...  ENSG00000097007
# 3           27,ABL2,ABLL,ARG,ENSG00000143322.19,P42684  ENSG00000143322
# 4    57007,ACKR3,CMKOR1,CXCR7,ENSG00000144476.5,GPR...  ENSG00000144476
# ..                                                 ...              ...
# 718             353088,ENSG00000197013.9,Q86V71,ZNF429  ENSG00000197013
# 719        90827,ENSG00000185177.12,KR19,Q96JC4,ZNF479  ENSG00000185177
# 720   25925,EHZF,ENSG00000198795.10,Evi3,Q96K83,ZNF521  ENSG00000198795
# 721  84133,BK747E2.3,ENSG00000183579.15,FLJ22057,KI...  ENSG00000183579
# 722  8233,ENSG00000169249.12,Q15696,U2AF1-RS2,U2AF1...  ENSG00000169249
#
# [723 rows x 21 columns]

# %%
# read in kidney genes
kidney_features = pd.read_csv('../figs_xgboost/xgboost_models/features_mapped_to_genes_ensembl.csv', header=None)[0]
kidney_features

# %%
# get overlapping genes
cosmic_overlap = cosmic[cosmic['ensembl_id'].isin(kidney_features)]

# also check for genes that didn't have an ensembl id
kidney_features_symbols = pd.read_csv('../figs_xgboost/xgboost_models/features_mapped_to_genes.csv', header=None)[0]
kidney_features_symbols

(cosmic[cosmic['ensembl_id'].isna()]['Gene Symbol'].isin(kidney_features_symbols)).sum() # none of them, so don't need to add any

# %%
cosmic_overlap.shape[0] # 190 kidney genes are in cosmic 
cosmic_overlap.shape[0]/cosmic.shape[0] # we capture over 25% of cosmic genes
cosmic_overlap.shape[0]/len(kidney_features) # around 3.7% of kidney genes are in cosmic

# %%
# now lets do a fishers test

# for this, we need the kidney gene background
kidney_background = pd.read_csv('../figs_xgboost/xgboost_models/input_features_for_background_gene_list_ensembl_ids.csv', header=None)[0]
kidney_background

# now lets make the 2x2 contingency matrix

kidney_features.isin(kidney_background).mean() # check, should be 1

len(kidney_background)
len(kidney_features)

len(cosmic['ensembl_id'])

cosmic_in_bg = cosmic['ensembl_id'][cosmic['ensembl_id'].isin(kidney_background)] # need just parts of cosmic that are in background
len(cosmic_in_bg)

cosmic_overlap['ensembl_id'].isin(kidney_background).mean() # should be 1


import numpy as np
cosmic_not_kidney = cosmic_in_bg[np.logical_not(cosmic_in_bg.isin(kidney_features))]

kidney_not_cosmic = kidney_features[np.logical_not(kidney_features.isin(cosmic_in_bg))]

not_cosmic_not_kidney = kidney_background[np.logical_not((kidney_background.isin(cosmic_in_bg)) | (kidney_background.isin(kidney_features)))]


contingency = pd.DataFrame({
                'cosmic': [len(cosmic_overlap['ensembl_id']), len(cosmic_not_kidney)], 
                'not_cosmic': [len(kidney_not_cosmic), len(not_cosmic_not_kidney)] 
              })
contingency.index = ['kidney', 'not_kidney']
contingency


from scipy.stats import fisher_exact
oddsr, p = fisher_exact(contingency, alternative='greater')
print('Oddsr is ', oddsr, ' and p is ', p)

# %%
# checking contingency maths is right
len(cosmic_in_bg)
190+463

len(kidney_features)
190+4821

len(kidney_background)
190+4821+463+22724

# %% [markdown]
# So yes, the features do have a significant overlap with COSMIC with p=4.676e-13
#
# There are 190 genes in both kidney genes and COSMIC genes

# %% [markdown]
# # dbEMT overlap

# %%
import pandas as pd
dbemt = pd.read_csv('dbEMTv2.csv')

dbemt['ensembl_id'] = dbemt['Links'].str.extract(r'Ensembl:(ENSG\d{11})')[0]
# was_na = dbemt['ensembl_id'].isna()
# dbemt[was_na]

# manually add missing ensembl ids
dbemt.loc[dbemt['GeneSymbol'] == 'DUXAP9', 'ensembl_id'] = 'ENSG00000225210'
dbemt.loc[dbemt['GeneSymbol'] == 'HAS2-AS1', 'ensembl_id'] = 'ENSG00000248690'
dbemt.loc[dbemt['GeneSymbol'] == 'MALAT1', 'ensembl_id'] = 'ENSG00000251562'
dbemt.loc[dbemt['GeneSymbol'] == 'MUC2', 'ensembl_id'] = 'ENSG00000198788'
dbemt.loc[dbemt['GeneSymbol'] == 'NANOGP8', 'ensembl_id'] = 'ENSG00000255192'
dbemt.loc[dbemt['GeneSymbol'] == 'TUG1', 'ensembl_id'] = 'ENSG00000253352'
dbemt.loc[dbemt['GeneSymbol'] == 'TUSC7', 'ensembl_id'] = 'ENSG00000243197'
dbemt.loc[dbemt['GeneSymbol'] == 'ZEB1-AS1', 'ensembl_id'] = 'ENSG00000237036'

# dbemt[was_na]
dbemt['ensembl_id'].isna().sum() # should be 0
# Out:
# 0

# %%
dbemt
# Out:
#       GeneID GeneSymbol                                              Alias  \
# 0       5243      ABCB1              ABC20|CD243|CLCS|GP170|MDR1|P-GP|PGY1
# 1       8714      ABCC3             ABC31|EST90757|MLP2|MOAT-D|MRP3|cMOAT2
# 2       9429      ABCG2  ABC15|ABCP|BCRP|BCRP1|BMDP|CD338|CDw338|EST157...
# 3      51554      ACKR4  CC-CKR-11|CCBP2|CCR-11|CCR10|CCR11|CCRL1|CCX C...
# 4         59      ACTA2                                   AAT6|ACTSA|MYMY5
# ...      ...        ...                                                ...
# 1179   23613     ZMYND8                              PRKCBP1|PRO2893|RACK7
# 1180    7702     ZNF143                                     SBF|STAF|pHZ-1
# 1181    7764     ZNF217                                              ZABC1
# 1182  155061     ZNF746                                              PARIS
# 1183    7791        ZYX                                        ESP-2|HED-2
#
#                                                   Links  Cytoband  \
# 0     MIM:171050|HGNC:HGNC:40|Ensembl:ENSG0000008556...   7q21.12
# 1     MIM:604323|HGNC:HGNC:54|Ensembl:ENSG0000010884...  17q21.33
# 2     MIM:603756|HGNC:HGNC:74|Ensembl:ENSG0000011877...    4q22.1
# 3     MIM:606065|HGNC:HGNC:1611|Ensembl:ENSG00000129...    3q22.1
# 4     MIM:102620|HGNC:HGNC:130|Ensembl:ENSG000001077...  10q23.31
# ...                                                 ...       ...
# 1179  MIM:615713|HGNC:HGNC:9397|Ensembl:ENSG00000101...  20q13.12
# 1180  MIM:603433|HGNC:HGNC:12928|Ensembl:ENSG0000016...   11p15.4
# 1181  MIM:602967|HGNC:HGNC:13009|Ensembl:ENSG0000017...   20q13.2
# 1182  MIM:613914|HGNC:HGNC:21948|Ensembl:ENSG0000018...    7q36.1
# 1183  MIM:602002|HGNC:HGNC:13200|Ensembl:ENSG0000015...      7q34
#
#                                                FullName        GeneType  \
# 0             ATP binding cassette subfamily B member 1  protein-coding
# 1             ATP binding cassette subfamily C member 3  protein-coding
# 2     ATP binding cassette subfamily G member 2 (Jun...  protein-coding
# 3                         atypical chemokine receptor 4  protein-coding
# 4                  actin, alpha 2, smooth muscle, aorta  protein-coding
# ...                                                 ...             ...
# 1179                 zinc finger MYND-type containing 8  protein-coding
# 1180                            zinc finger protein 143  protein-coding
# 1181                            zinc finger protein 217  protein-coding
# 1182                            zinc finger protein 746  protein-coding
# 1183                                              zyxin  protein-coding
#
#       Unnamed: 7  Unnamed: 8                         Unnamed: 9  \
# 0            NaN         NaN  http://dbemt.bioinfo-minzhao.org/
# 1            NaN         NaN                                NaN
# 2            NaN         NaN                                NaN
# 3            NaN         NaN                                NaN
# 4            NaN         NaN                                NaN
# ...          ...         ...                                ...
# 1179         NaN         NaN                                NaN
# 1180         NaN         NaN                                NaN
# 1181         NaN         NaN                                NaN
# 1182         NaN         NaN                                NaN
# 1183         NaN         NaN                                NaN
#
#            ensembl_id
# 0     ENSG00000085563
# 1     ENSG00000108846
# 2     ENSG00000118777
# 3     ENSG00000129048
# 4     ENSG00000107796
# ...               ...
# 1179  ENSG00000101040
# 1180  ENSG00000166478
# 1181  ENSG00000171940
# 1182  ENSG00000181220
# 1183  ENSG00000159840
#
# [1184 rows x 11 columns]

# %%
# read in kidney genes
kidney_features = pd.read_csv('../figs_xgboost/xgboost_models/features_mapped_to_genes_ensembl.csv', header=None)[0]
kidney_features
# Out:
# 0       ENSG00000103479
# 1       ENSG00000111364
# 2       ENSG00000128011
# 3       ENSG00000169962
# 4       ENSG00000117477
#              ...
# 5006    ENSG00000275888
# 5007    ENSG00000249628
# 5008    ENSG00000173548
# 5009    ENSG00000177971
# 5010    ENSG00000179284
# Name: 0, Length: 5011, dtype: object

# %%
# get overlapping genes
dbemt_overlap = dbemt[dbemt['ensembl_id'].isin(kidney_features)]
dbemt_overlap
# Out:
#          GeneID GeneSymbol                              Alias  \
# 7            81      ACTN4               ACTININ-4|FSGS|FSGS1
# 13          133        ADM                            AM|PAMP
# 21        84962      AJUBA                                JUB
# 28          238        ALK                       CD246|NBLST3
# 31          283        ANG     ALS9|HEL168|RAA1|RNASE4|RNASE5
# ...         ...        ...                                ...
# 1165      10413       YAP1            COB1|YAP|YAP2|YAP65|YKI
# 1168       7532      YWHAG               14-3-3GAMMA|PPP1R170
# 1174       9839       ZEB2  HSPC082|SIP-1|SIP1|SMADIP1|ZFHX1B
# 1175  100303491   ZEB2-AS1             ZEB2-AS|ZEB2AS|ZEB2NAT
# 1181       7764     ZNF217                              ZABC1
#
#                                                   Links      Cytoband  \
# 7     MIM:604638|HGNC:HGNC:166|Ensembl:ENSG000001304...       19q13.2
# 13    MIM:103275|HGNC:HGNC:259|Ensembl:ENSG000001489...       11p15.4
# 21    MIM:609066|HGNC:HGNC:20250|Ensembl:ENSG0000012...       14q11.2
# 28    MIM:105590|HGNC:HGNC:427|Ensembl:ENSG000001710...  2p23.2-p23.1
# 31    MIM:105850|HGNC:HGNC:483|Ensembl:ENSG000002142...       14q11.2
# ...                                                 ...           ...
# 1165  MIM:606608|HGNC:HGNC:16262|Ensembl:ENSG0000013...       11q22.1
# 1168  MIM:605356|HGNC:HGNC:12852|Ensembl:ENSG0000017...       7q11.23
# 1174  MIM:605802|HGNC:HGNC:14881|Ensembl:ENSG0000016...        2q22.3
# 1175            HGNC:HGNC:37149|Ensembl:ENSG00000238057        2q22.3
# 1181  MIM:602967|HGNC:HGNC:13009|Ensembl:ENSG0000017...       20q13.2
#
#                                                FullName        GeneType  \
# 7                                       actinin alpha 4  protein-coding
# 13                                       adrenomedullin  protein-coding
# 21                                    ajuba LIM protein  protein-coding
# 28                         ALK receptor tyrosine kinase  protein-coding
# 31                                           angiogenin  protein-coding
# ...                                                 ...             ...
# 1165                           Yes associated protein 1  protein-coding
# 1168  tyrosine 3-monooxygenase/tryptophan 5-monooxyg...  protein-coding
# 1174               zinc finger E-box binding homeobox 2  protein-coding
# 1175                               ZEB2 antisense RNA 1           ncRNA
# 1181                            zinc finger protein 217  protein-coding
#
#       Unnamed: 7  Unnamed: 8 Unnamed: 9       ensembl_id
# 7            NaN         NaN        NaN  ENSG00000130402
# 13           NaN         NaN        NaN  ENSG00000148926
# 21           NaN         NaN        NaN  ENSG00000129474
# 28           NaN         NaN        NaN  ENSG00000171094
# 31           NaN         NaN        NaN  ENSG00000214274
# ...          ...         ...        ...              ...
# 1165         NaN         NaN        NaN  ENSG00000137693
# 1168         NaN         NaN        NaN  ENSG00000170027
# 1174         NaN         NaN        NaN  ENSG00000169554
# 1175         NaN         NaN        NaN  ENSG00000238057
# 1181         NaN         NaN        NaN  ENSG00000171940
#
# [294 rows x 11 columns]

# %%
dbemt_overlap
dbemt_overlap.shape[0] # 294 kidney genes are in dbemt
dbemt_overlap.shape[0]/dbemt.shape[0] # we capture around 25% of dbemt genes
dbemt_overlap.shape[0]/len(kidney_features) # around 5-6% of kidney genes are in dbemt
# Out:
#          GeneID GeneSymbol                              Alias  \
# 7            81      ACTN4               ACTININ-4|FSGS|FSGS1
# 13          133        ADM                            AM|PAMP
# 21        84962      AJUBA                                JUB
# 28          238        ALK                       CD246|NBLST3
# 31          283        ANG     ALS9|HEL168|RAA1|RNASE4|RNASE5
# ...         ...        ...                                ...
# 1165      10413       YAP1            COB1|YAP|YAP2|YAP65|YKI
# 1168       7532      YWHAG               14-3-3GAMMA|PPP1R170
# 1174       9839       ZEB2  HSPC082|SIP-1|SIP1|SMADIP1|ZFHX1B
# 1175  100303491   ZEB2-AS1             ZEB2-AS|ZEB2AS|ZEB2NAT
# 1181       7764     ZNF217                              ZABC1
#
#                                                   Links      Cytoband  \
# 7     MIM:604638|HGNC:HGNC:166|Ensembl:ENSG000001304...       19q13.2
# 13    MIM:103275|HGNC:HGNC:259|Ensembl:ENSG000001489...       11p15.4
# 21    MIM:609066|HGNC:HGNC:20250|Ensembl:ENSG0000012...       14q11.2
# 28    MIM:105590|HGNC:HGNC:427|Ensembl:ENSG000001710...  2p23.2-p23.1
# 31    MIM:105850|HGNC:HGNC:483|Ensembl:ENSG000002142...       14q11.2
# ...                                                 ...           ...
# 1165  MIM:606608|HGNC:HGNC:16262|Ensembl:ENSG0000013...       11q22.1
# 1168  MIM:605356|HGNC:HGNC:12852|Ensembl:ENSG0000017...       7q11.23
# 1174  MIM:605802|HGNC:HGNC:14881|Ensembl:ENSG0000016...        2q22.3
# 1175            HGNC:HGNC:37149|Ensembl:ENSG00000238057        2q22.3
# 1181  MIM:602967|HGNC:HGNC:13009|Ensembl:ENSG0000017...       20q13.2
#
#                                                FullName        GeneType  \
# 7                                       actinin alpha 4  protein-coding
# 13                                       adrenomedullin  protein-coding
# 21                                    ajuba LIM protein  protein-coding
# 28                         ALK receptor tyrosine kinase  protein-coding
# 31                                           angiogenin  protein-coding
# ...                                                 ...             ...
# 1165                           Yes associated protein 1  protein-coding
# 1168  tyrosine 3-monooxygenase/tryptophan 5-monooxyg...  protein-coding
# 1174               zinc finger E-box binding homeobox 2  protein-coding
# 1175                               ZEB2 antisense RNA 1           ncRNA
# 1181                            zinc finger protein 217  protein-coding
#
#       Unnamed: 7  Unnamed: 8 Unnamed: 9       ensembl_id
# 7            NaN         NaN        NaN  ENSG00000130402
# 13           NaN         NaN        NaN  ENSG00000148926
# 21           NaN         NaN        NaN  ENSG00000129474
# 28           NaN         NaN        NaN  ENSG00000171094
# 31           NaN         NaN        NaN  ENSG00000214274
# ...          ...         ...        ...              ...
# 1165         NaN         NaN        NaN  ENSG00000137693
# 1168         NaN         NaN        NaN  ENSG00000170027
# 1174         NaN         NaN        NaN  ENSG00000169554
# 1175         NaN         NaN        NaN  ENSG00000238057
# 1181         NaN         NaN        NaN  ENSG00000171940
#
# [294 rows x 11 columns]
# 294
# 0.2483108108108108
# 0.058670923967272

# %%
# now lets do a fishers test

# for this, we need the kidney gene background
kidney_background = pd.read_csv('../figs_xgboost/xgboost_models/input_features_for_background_gene_list_ensembl_ids.csv', header=None)[0]
kidney_background


# now lets make the 2x2 contingency matrix
kidney_features.isin(kidney_background).mean() # check, should be 1

len(kidney_background)
len(kidney_features)

len(dbemt['ensembl_id'])

dbemt_in_bg = dbemt['ensembl_id'][dbemt['ensembl_id'].isin(kidney_background)] # need just parts of cosmic that are in background
len(dbemt_in_bg)

dbemt_overlap['ensembl_id'].isin(kidney_background).mean() # should be 1


import numpy as np
dbemt_not_kidney = dbemt_in_bg[np.logical_not(dbemt_in_bg.isin(kidney_features))]

kidney_not_dbemt = kidney_features[np.logical_not(kidney_features.isin(dbemt_in_bg))]

not_dbemt_not_kidney = kidney_background[np.logical_not((kidney_background.isin(dbemt_in_bg)) | (kidney_background.isin(kidney_features)))]


contingency = pd.DataFrame({
                'dbemt': [len(dbemt_overlap['ensembl_id']), len(dbemt_not_kidney)], 
                'not_dbemt': [len(kidney_not_dbemt), len(not_dbemt_not_kidney)] 
              })
contingency.index = ['kidney', 'not_kidney']
contingency


from scipy.stats import fisher_exact
oddsr, p = fisher_exact(contingency, alternative='greater')
print('Oddsr is ', oddsr, ' and p is ', p)
# Out:
# 0        ENSG00000103479
# 1        ENSG00000168405
# 2        ENSG00000079691
# 3        ENSG00000169714
# 4        ENSG00000111364
#               ...
# 28193    ENSG00000284585
# 28194    ENSG00000260121
# 28195    ENSG00000287982
# 28196    ENSG00000256695
# 28197    ENSG00000213065
# Name: 0, Length: 28198, dtype: object
# 1.0
# 28198
# 5011
# 1184
# 1055
# 1.0
#             dbemt  not_dbemt
# kidney        294       4717
# not_kidney    761      22426
# Oddsr is  1.8367439381753643  and p is  1.0319735527032817e-16

# %%
# checking contingency maths is right
len(dbemt_in_bg)
294+761

len(kidney_features)
294+4717

len(kidney_background)
294+4717+761+22426
# Out:
# 1055
# 1055
# 5011
# 5011
# 28198
# 28198

# %% [markdown]
# ### HCMDB overlap

# %%
# read in HCMDB
import pandas as pd
hcmdb = pd.read_csv('Metastatic Genes from HCMDB - Sheet1.csv')
hcmdb = hcmdb['gene'].drop_duplicates().str.upper()
len(hcmdb)
list(hcmdb)
# Out:
# 2240
# ['AAMP',
#  'ABCA2',
#  'ABCB1',
#  'ABCC5',
#  'ABCG2',
#  'ABI1',
#  'ABI2',
#  'ABL1',
#  'ABL2',
#  'ACE',
#  'ACE2',
#  'ACKR1',
#  'ACKR2',
#  'ACKR3',
#  'ACOT8',
#  'ACP5',
#  'ACTA2',
#  'ACTB',
#  'ACTL6A',
#  'ACTN4',
#  'ACTR2',
#  'ACTR3',
#  'ACVR1C',
#  'ADAM10',
#  'ADAM12',
#  'ADAM15',
#  'ADAM17',
#  'ADAM23',
#  'ADAM28',
#  'ADAM8',
#  'ADAM9',
#  'ADAMTS1',
#  'ADAMTS13',
#  'ADAMTS18',
#  'ADGRE5',
#  'ADGRF5',
#  'ADGRG1',
#  'ADGRL3',
#  'ADIPOQ',
#  'ADM',
#  'ADORA2B',
#  'ADRB2',
#  'AFAP1-AS1',
#  'AFAP1L1',
#  'AFAP1L2',
#  'AFDN',
#  'AFP',
#  'AGER',
#  'AGO1',
#  'AGO2',
#  'AGO4',
#  'AGR2',
#  'AGR3',
#  'AGT',
#  'AGTR1',
#  'AGTR2',
#  'AHR',
#  'AIFM1',
#  'AJUBA',
#  'AKAP12',
#  'AKR1C2',
#  'AKR1C3',
#  'AKT1',
#  'AKT2',
#  'AKT3',
#  'ALCAM',
#  'ALDH1A1',
#  'ALDH1A3',
#  'ALDH3A1',
#  'ALDH7A1',
#  'ALDOA',
#  'ALK',
#  'ALOX15',
#  'ALOX5',
#  'ALPL',
#  'ALPP',
#  'ALYREF',
#  'AMACR',
#  'AMBP',
#  'AMFR',
#  'AMOT',
#  'ANGPT1',
#  'ANGPT2',
#  'ANGPTL2',
#  'ANGPTL4',
#  'ANGPTL6',
#  'ANKRD12',
#  'ANO1',
#  'ANO9',
#  'ANOS1',
#  'ANTXR1',
#  'ANXA1',
#  'ANXA2',
#  'ANXA2R',
#  'ANXA3',
#  'ANXA4',
#  'ANXA7',
#  'APAF1',
#  'APBA2',
#  'APC',
#  'APEX1',
#  'API5',
#  'APMAP',
#  'APOBEC3G',
#  'APOM',
#  'AQP1',
#  'AQP3',
#  'AQP5',
#  'AQP8',
#  'AR',
#  'ARF6',
#  'ARG1',
#  'ARHGAP35',
#  'ARHGAP5',
#  'ARHGDIA',
#  'ARHGDIB',
#  'ARHGEF1',
#  'ARHGEF2',
#  'ARHGEF39',
#  'ARID1A',
#  'ARID4A',
#  'ARID4B',
#  'ARL2BP',
#  'ARL6IP5',
#  'ARMC8',
#  'ARNT',
#  'ARNTL',
#  'ARRB1',
#  'ARTN',
#  'ASAP1',
#  'ASCL2',
#  'ASPN',
#  'ASS1',
#  'ATAD2',
#  'ATF3',
#  'ATF4',
#  'ATG10',
#  'ATM',
#  'ATP11A',
#  'ATP2A3',
#  'ATP5B',
#  'ATP6V1C1',
#  'ATPIF1',
#  'AURKA',
#  'AURKB',
#  'AUTS2',
#  'AXIN2',
#  'AXL',
#  'B2M',
#  'B3GAT1',
#  'B3GNT3',
#  'B3GNT7',
#  'B3GNT8',
#  'B4GALT1',
#  'B4GALT3',
#  'BAD',
#  'BAG1',
#  'BAG2',
#  'BAG3',
#  'BAIAP2',
#  'BAK1',
#  'BAP1',
#  'BAX',
#  'BAZ2A',
#  'BBC3',
#  'BCAM',
#  'BCAR1',
#  'BCAR4',
#  'BCAT1',
#  'BCL2',
#  'BCL2L1',
#  'BCL2L11',
#  'BCL2L12',
#  'BCL2L2',
#  'BCL9',
#  'BDKRB2',
#  'BDNF',
#  'BECN1',
#  'BGN',
#  'BIN1',
#  'BIRC2',
#  'BIRC3',
#  'BIRC5',
#  'BIRC7',
#  'BLACAT1',
#  'BMI1',
#  'BMP1',
#  'BMP2',
#  'BMP4',
#  'BMP5',
#  'BMP6',
#  'BMP7',
#  'BNIP3',
#  'BRAF',
#  'BRCA1',
#  'BRCA2',
#  'BRD7',
#  'BRMS1',
#  'BRS3',
#  'BSG',
#  'BST2',
#  'BTG1',
#  'BVES',
#  'C14ORF166',
#  'C1QA',
#  'C1QBP',
#  'C6ORF106',
#  'CA1',
#  'CA2',
#  'CA9',
#  'CACUL1',
#  'CACYBP',
#  'CADM1',
#  'CALCA',
#  'CALR',
#  'CALU',
#  'CAMP',
#  'CANX',
#  'CAP1',
#  'CAPG',
#  'CAPNS1',
#  'CARD10',
#  'CARD9',
#  'CASP10',
#  'CASP3',
#  'CASP8',
#  'CASP9',
#  'CASS4',
#  'CAT',
#  'CAV1',
#  'CBL',
#  'CBLB',
#  'CBR1',
#  'CBR3',
#  'CBR3-AS1',
#  'CBX4',
#  'CBX5',
#  'CBX7',
#  'CBX8',
#  'CCAR2',
#  'CCDC88A',
#  'CCDC88C',
#  'CCL1',
#  'CCL14',
#  'CCL18',
#  'CCL19',
#  'CCL2',
#  'CCL21',
#  'CCL22',
#  'CCL3',
#  'CCL5',
#  'CCL7',
#  'CCL8',
#  'CCNA2',
#  'CCNB1',
#  'CCNB2',
#  'CCND1',
#  'CCND2',
#  'CCNG1',
#  'CCNG2',
#  'CCR1',
#  'CCR4',
#  'CCR5',
#  'CCR6',
#  'CCR7',
#  'CCR9',
#  'CD109',
#  'CD14',
#  'CD151',
#  'CD164',
#  'CD200',
#  'CD22',
#  'CD24',
#  'CD274',
#  'CD276',
#  'CD34',
#  'CD4',
#  'CD40',
#  'CD44',
#  'CD47',
#  'CD55',
#  'CD63',
#  'CD74',
#  'CD80',
#  'CD81',
#  'CD82',
#  'CD9',
#  'CDC42',
#  'CDC73',
#  'CDCA8',
#  'CDCP1',
#  'CDH1',
#  'CDH11',
#  'CDH12',
#  'CDH13',
#  'CDH17',
#  'CDH2',
#  'CDH3',
#  'CDK1',
#  'CDK4',
#  'CDK5RAP3',
#  'CDK8',
#  'CDKN1A',
#  'CDKN1B',
#  'CDKN2A',
#  'CDKN2B-AS1',
#  'CDX2',
#  'CEACAM1',
#  'CEACAM3',
#  'CEACAM5',
#  'CEACAM6',
#  'CEBPA',
#  'CEBPB',
#  'CEMIP',
#  'CENPW',
#  'CERS2',
#  'CERS6',
#  'CETN1',
#  'CFL1',
#  'CFTR',
#  'CHAF1B',
#  'CHD1L',
#  'CHEK1',
#  'CHEK2',
#  'CHFR',
#  'CHGA',
#  'CHI3L1',
#  'CHRM3',
#  'CHRNA4',
#  'CHRNA7',
#  'CHUK',
#  'CITED1',
#  'CITED2',
#  'CKS1B',
#  'CLCA1',
#  'CLCA2',
#  'CLCN3',
#  'CLDN1',
#  'CLDN11',
#  'CLDN16',
#  'CLDN18',
#  'CLDN3',
#  'CLDN4',
#  'CLDN5',
#  'CLDN7',
#  'CLEC1B',
#  'CLEC2A',
#  'CLEC4G',
#  'CLEC4M',
#  'CLIC1',
#  'CLIC3',
#  'CLIC4',
#  'CLIP1',
#  'CLOCK',
#  'CLU',
#  'CMTM3',
#  'CNBP',
#  'CNDP1',
#  'CNR1',
#  'CNTN1',
#  'COL18A1',
#  'COL1A1',
#  'COL3A1',
#  'COL4A6',
#  'COPS3',
#  'CORO1C',
#  'COX2',
#  'CPE',
#  'CPEB2',
#  'CPEB4',
#  'CPNE3',
#  'CR1',
#  'CRABP2',
#  'CREB1',
#  'CREB3',
#  'CREB5',
#  'CREM',
#  'CRIM1',
#  'CRK',
#  'CRKL',
#  'CRMP1',
#  'CRNN',
#  'CRP',
#  'CRTC2',
#  'CRYAB',
#  'CSE1L',
#  'CSF1',
#  'CSNK1A1',
#  'CSNK2A1',
#  'CSNK2B',
#  'CSPG4',
#  'CST3',
#  'CST6',
#  'CSTA',
#  'CT45A1',
#  'CTAG1B',
#  'CTGF',
#  'CTHRC1',
#  'CTLA4',
#  'CTNNA1',
#  'CTNNA3',
#  'CTNNAL1',
#  'CTNNB1',
#  'CTNND1',
#  'CTNND2',
#  'CTSB',
#  'CTSD',
#  'CTSH',
#  'CTSK',
#  'CTSL',
#  'CTSS',
#  'CTSZ',
#  'CTTN',
#  'CUL1',
#  'CUX1',
#  'CX3CR1',
#  'CXADR',
#  'CXCL1',
#  'CXCL10',
#  'CXCL12',
#  'CXCL14',
#  'CXCL2',
#  'CXCL3',
#  'CXCL6',
#  'CXCL8',
#  'CXCR1',
#  'CXCR2',
#  'CXCR3',
#  'CXCR4',
#  'CXCR5',
#  'CXCR6',
#  'CXXC4',
#  'CYB5R3',
#  'CYCS',
#  'CYLD',
#  'CYP19A1',
#  'CYP1A1',
#  'CYP1B1',
#  'CYP2J2',
#  'CYP3A4',
#  'CYP3A5',
#  'CYR61',
#  'DAB2',
#  'DAB2IP',
#  'DACH1',
#  'DACH2',
#  'DACT2',
#  'DAG1',
#  'DAPK1',
#  'DDA1',
#  'DDB2',
#  'DDIT3',
#  'DDR1',
#  'DDR2',
#  'DEFB103B',
#  'DEK',
#  'DEPDC1B',
#  'DEPTOR',
#  'DHFR',
#  'DIABLO',
#  'DIAPH1',
#  'DICER1',
#  'DIRAS1',
#  'DIRAS3',
#  'DIXDC1',
#  'DKK1',
#  'DKK3',
#  'DKK4',
#  'DLC1',
#  'DLEC1',
#  'DLL1',
#  'DLL4',
#  'DLX4',
#  'DNAJA3',
#  'DNAJB4',
#  'DNAJB6',
#  'DNM2',
#  'DNMT3A',
#  'DNMT3B',
#  'DOCK1',
#  'DOCK4',
#  'DPEP1',
#  'DPP4',
#  'DPPA2',
#  'DPYD',
#  'DPYSL3',
#  'DRG1',
#  'DROSHA',
#  'DSC3',
#  'DSG3',
#  'DUSP1',
#  'DUSP6',
#  'DVL2',
#  'E2F1',
#  'E2F3',
#  'EBAG9',
#  'ECE1',
#  'ECE2',
#  'ECM1',
#  'ECT2',
#  'EDN1',
#  'EDNRA',
#  'EDNRB',
#  'EFEMP1',
#  'EFNB1',
#  'EFNB2',
#  'EGF',
#  'EGFL7',
#  'EGFR',
#  'EGLN3',
#  'EGR1',
#  'EGR3',
#  'EHD2',
#  'EHMT2',
#  'EIF1AX',
#  'EIF3I',
#  'EIF4B',
#  'EIF4E',
#  'EIF4EBP1',
#  'EIF5A2',
#  'EIF6',
#  'ELAVL1',
#  'ELAVL4',
#  'ELF1',
#  'ELF5',
#  'ELK3',
#  'ELMO1',
#  'EMP1',
#  'EMP3',
#  'EMSY',
#  'ENAH',
#  'ENG',
#  'ENO1',
#  'ENO2',
#  'ENPP1',
#  'ENPP2',
#  'ENTPD1',
#  'EP300',
#  'EPAS1',
#  'EPB41L3',
#  'EPC1',
#  'EPCAM',
#  'EPHA1',
#  'EPHA10',
#  'EPHA2',
#  'EPHA4',
#  'EPHA7',
#  'EPHB1',
#  'EPHB2',
#  'EPHB3',
#  'EPHB4',
#  'EPO',
#  'EPOR',
#  'EPS8',
#  'EPSTI1',
#  'ERAP1',
#  'ERAS',
#  'ERBB2',
#  'ERBB3',
#  'ERBB4',
#  'ERCC1',
#  'EREG',
#  'ERG',
#  'ERP29',
#  'ESAM',
#  'ESM1',
#  'ESR1',
#  'ESR2',
#  'ESRP1',
#  'ETS1',
#  'ETS2',
#  'ETV1',
#  'ETV4',
#  'ETV7',
#  'EVI5',
#  'EVL',
#  'EYA2',
#  'EZH2',
#  'EZR',
#  'F11R',
#  'F2',
#  'F2R',
#  'F2RL1',
#  'F3',
#  'F7',
#  'FABP1',
#  'FABP3',
#  'FABP5',
#  'FADD',
#  'FAIM2',
#  'FAM120A',
#  'FAM134A',
#  'FAM3B',
#  'FANCD2',
#  'FAP',
#  'FAS',
#  'FASLG',
#  'FASN',
#  'FBLN5',
#  'FBN1',
#  'FBN2',
#  'FBXO11',
#  'FBXW7',
#  'FCGRT',
#  'FDFT1',
#  'FENDRR',
#  'FER',
#  'FERMT1',
#  'FERMT2',
#  'FERMT3',
#  'FGF1',
#  'FGF11',
#  'FGF19',
#  'FGF2',
#  'FGF8',
#  'FGFBP1',
#  'FGFR1',
#  'FGFR2',
#  'FGFR3',
#  'FGFR4',
#  'FGL2',
#  'FHIT',
#  'FHL2',
#  'FILIP1',
#  'FKBP5',
#  'FLI1',
#  'FLNA',
#  'FLOT1',
#  'FLOT2',
#  'FLT1',
#  'FLT4',
#  'FMNL2',
#  'FMNL3',
#  'FN1',
#  'FNDC3B',
#  'FOLH1',
#  'FOS',
#  'FOSB',
#  'FOSL1',
#  'FOXA2',
#  'FOXC1',
#  'FOXC2',
#  'FOXD3',
#  'FOXE1',
#  'FOXF2',
#  'FOXJ1',
#  'FOXJ2',
#  'FOXK1',
#  'FOXL1',
#  'FOXM1',
#  'FOXN3',
#  'FOXO1',
#  'FOXO3',
#  'FOXO4',
#  'FOXP3',
#  'FOXQ1',
#  'FPR2',
#  'FRAT1',
#  'FSCN1',
#  'FSCN2',
#  'FST',
#  'FSTL1',
#  'FUBP1',
#  'FURIN',
#  'FUS',
#  'FXR1',
#  'FXYD3',
#  'FXYD5',
#  'FYN',
#  'FZD2',
#  'FZD7',
#  'G3BP1',
#  'G3BP2',
#  'G6PD',
#  'GAB1',
#  'GAB2',
#  'GABRA3',
#  'GADD45A',
#  'GAL3ST2',
#  'GALNT3',
#  'GAS1',
#  'GAS5',
#  'GAS6',
#  'GATA3',
#  'GATA4',
#  'GATA6',
#  'GBP2',
#  'GCNT1',
#  'GCNT2',
#  'GDF15',
#  'GDF2',
#  'GDNF',
#  'GEMIN2',
#  'GFRA1',
#  'GGCT',
#  'GHITM',
#  'GHR',
#  'GHRL',
#  'GIT1',
#  'GJA1',
#  'GJB1',
#  'GJB2',
#  'GKN1',
#  'GKN2',
#  'GLG1',
#  'GLI1',
#  'GLI2',
#  'GLI3',
#  'GLRX3',
#  'GMNN',
#  'GNA12',
#  'GNA13',
#  'GNAI1',
#  'GNB3',
#  'GNPTG',
#  'GNRH2',
#  'GOLPH3',
#  'GPAT3',
#  'GPC3',
#  'GPC5',
#  'GPER1',
#  'GPI',
#  'GPNMB',
#  'GPR4',
#  'GPR68',
#  'GPR87',
#  'GPX1',
#  'GPX3',
#  'GRB2',
#  'GRB7',
#  'GRINA',
#  'GRM4',
#  'GRN',
#  'GSC',
#  'GSDMB',
#  'GSK3B',
#  'GSN',
#  'GSTM1',
#  'GSTM3',
#  'GSTP1',
#  'GSTT1',
#  'GUSB',
#  'GZMB',
#  'H19',
#  'H2AFX',
#  'HAMP',
#  'HAS1',
#  'HAX1',
#  'HBEGF',
#  'HDAC1',
#  'HDAC10',
#  'HDAC2',
#  'HDAC4',
#  'HDGF',
#  'HES1',
#  'HEY1',
#  'HGF',
#  'HIC1',
#  'HIF1A',
#  'HIP1',
#  'HIST3H3',
#  'HK1',
#  'HK2',
#  'HLA-E',
#  'HLA-G',
#  'HMGA1',
#  'HMGA2',
#  'HMGB1',
#  'HMMR',
#  'HMOX1',
#  'HNF1A',
#  'HNF1A-AS1',
#  'HNF4A',
#  'HNRNPA1',
#  'HNRNPAB',
#  'HNRNPD',
#  'HNRNPK',
#  'HNRNPM',
#  'HOMER1',
#  'HOPX',
#  'HOTAIR',
#  'HOXA1',
#  'HOXA5',
#  'HOXA9',
#  'HOXB13',
#  'HOXB5',
#  'HOXB7',
#  'HOXB9',
#  'HOXC8',
#  'HOXD9',
#  'HP',
#  'HPN',
#  'HPSE',
#  'HPSE2',
#  'HRAS',
#  'HRC',
#  'HRG',
#  'HSF1',
#  'HSP90AA1',
#  'HSP90AA2P',
#  'HSP90AB1',
#  'HSP90B1',
#  'HSPA4',
#  'HSPA5',
#  'HSPA9',
#  'HSPB1',
#  'HSPB2',
#  'HSPD1',
#  'HTATIP2',
#  'HTRA1',
#  'HTRA2',
#  'HTRA3',
#  'HTT',
#  'HULC',
#  'HVCN1',
#  'HYAL1',
#  'HYAL3',
#  'IBSP',
#  'ICAM1',
#  'ID1',
#  'ID2',
#  'ID3',
#  'IDH1',
#  'IDO1',
#  'IFIT2',
#  'IFITM1',
#  'IFNAR2',
#  'IFNG',
#  'IGF1',
#  'IGF1R',
#  'IGF2BP1',
#  'IGF2BP3',
#  'IGFBP1',
#  'IGFBP2',
#  'IGFBP3',
#  'IGFBP4',
#  'IGFBP5',
#  'IGFBP7',
#  'IGSF8',
#  'IHH',
#  'IKBKB',
#  'IKBKE',
#  'IL10',
#  'IL11',
#  'IL12A',
#  'IL13',
#  'IL13RA1',
#  'IL13RA2',
#  'IL17A',
#  'IL17RA',
#  'IL17RB',
#  'IL18',
#  'IL19',
#  'IL1A',
#  'IL1B',
#  'IL1RL1',
#  'IL2',
#  'IL22',
#  'IL23A',
#  'IL24',
#  'IL2RG',
#  'IL32',
#  'IL34',
#  'IL4',
#  'IL4R',
#  'IL5',
#  'IL6',
#  'IL7',
#  'IL7R',
#  'ILK',
#  'IMP3',
#  'ING1',
#  'ING4',
#  'ING5',
#  'INHBA',
#  'INHBC',
#  'INPP4B',
#  'INPPL1',
#  'INS',
#  'IQGAP1',
#  'IQSEC1',
#  'IRAK1',
#  'IRF7',
#  'IRS1',
#  'IRS2',
#  'IRX1',
#  'IRX2',
#  'ISG15',
#  'ITGA2',
#  'ITGA3',
#  'ITGA4',
#  'ITGA5',
#  'ITGA6',
#  'ITGAM',
#  'ITGAV',
#  'ITGB1',
#  'ITGB2',
#  'ITGB3',
#  'ITGB3BP',
#  'ITGB4',
#  'ITGB5',
#  'ITGB6',
#  'ITGB8',
#  'ITIH1',
#  'ITIH3',
#  'IVNS1ABP',
#  'JAG1',
#  'JAG2',
#  'JAK1',
#  'JAK2',
#  'JAM3',
#  'JDP2',
#  'JUN',
#  'JUP',
#  'KARS',
#  'KAT5',
#  'KATNA1',
#  'KCNH1',
#  'KCNJ1',
#  'KCNMA1',
#  'KCNN4',
#  'KDM1A',
#  'KDM3A',
#  'KDM4B',
#  'KDM4C',
#  'KDM5A',
#  'KDM6B',
#  'KDR',
#  'KEAP1',
#  'KHDRBS1',
#  'KIAA0100',
#  'KIAA1524',
#  'KIF14',
#  'KIF2C',
#  'KIF3C',
#  'KIR2DL4',
#  'KISS1',
#  'KISS1R',
#  'KIT',
#  'KITLG',
#  'KL',
#  'KLF17',
#  'KLF2',
#  'KLF4',
#  'KLF5',
#  'KLF6',
#  'KLF8',
#  'KLK13',
#  'KLK3',
#  'KLK4',
#  'KLK6',
#  'KLK7',
#  'KLK8',
#  'KMT5A',
#  'KNG1',
#  'KRAS',
#  'KRT14',
#  'KRT17',
#  'KRT18',
#  'KRT19',
#  'KRT20',
#  'KRT34',
#  'KRT5',
#  'KRT6A',
#  'KRT7',
#  'KRT75',
#  'KRT8',
#  'L1CAM',
#  'L1RE1',
#  'LAMA5',
#  'LAMB3',
#  'LAMC2',
#  'LAMP3',
#  'LAMTOR1',
#  'LAP3',
#  'LAPTM4B',
#  'LARGE1',
#  'LARGE2',
#  'LARP7',
#  'LASP1',
#  'LAT',
#  'LATS2',
#  'LCN2',
#  'LCP1',
#  'LDHA',
#  'LECT1',
#  'LEF1',
#  'LEP',
#  'LEPQTL1',
#  'LEPR',
#  'LGALS1',
#  'LGALS2',
#  'LGALS3',
#  'LGALS3BP',
#  'LGALS8',
#  'LGALS9',
#  'LGI1',
#  'LGI4',
#  'LGR4',
#  'LGR5',
#  ...]

# %%
# read in kidney genes
kidney_features = pd.read_csv('../figs_xgboost/xgboost_models/features_mapped_to_genes.csv', header=None)[0]
kidney_features = kidney_features.str.upper()
kidney_features
# Out:
# 0            RBL2
# 1           DDX55
# 2           LRFN1
# 3          TAS1R3
# 4         CCDC181
#           ...
# 4211       CSNK1D
# 4212    LINC00942
# 4213        SNX33
# 4214         IMP3
# 4215        DAND5
# Name: 0, Length: 4216, dtype: object

# %%
# get overlapping genes

hcmdb_overlap = hcmdb[hcmdb.isin(kidney_features)]
hcmdb_overlap

len(hcmdb_overlap)
len(hcmdb_overlap)/len(hcmdb) # 21% of hcmdb genes
len(hcmdb_overlap)/len(kidney_features) # 11% of kidney genes
# Out:
# 11        ABL1
# 18       ACKR2
# 39        ACTB
# 41       ACTN4
# 47      ACVR1C
#          ...
# 6581    ZDHHC2
# 6601      ZEB2
# 6614     ZFHX3
# 6619    ZNF217
# 6626    ZNF703
# Name: gene, Length: 478, dtype: object
# 478
# 0.21339285714285713
# 0.11337760910815939

# %%
# now lets do a fishers test

# for this, we need the kidney gene background
kidney_background = pd.read_csv('../figs_xgboost/xgboost_models/input_features_for_background_gene_list_symbols.csv', header=None)[0]
kidney_background = kidney_background.str.upper()
kidney_background


# now lets make the 2x2 contingency matrix

kidney_features.isin(kidney_background).mean() # check, should be 1

len(kidney_background)
len(kidney_features)

len(hcmdb)

hcmdb_in_bg = hcmdb[hcmdb.isin(kidney_background)] # need just parts of cosmic that are in background
len(hcmdb_in_bg)

hcmdb_overlap.isin(kidney_background).mean() # should be 1


import numpy as np
hcmdb_not_kidney = hcmdb_in_bg[np.logical_not(hcmdb_in_bg.isin(kidney_features))]

kidney_not_hcmdb = kidney_features[np.logical_not(kidney_features.isin(hcmdb_in_bg))]

not_hcmdb_not_kidney = kidney_background[np.logical_not((kidney_background.isin(hcmdb_in_bg)) | (kidney_background.isin(kidney_features)))]


contingency = pd.DataFrame({
                'hcmdb': [len(hcmdb_overlap), len(hcmdb_not_kidney)], 
                'not_hcmdb': [len(kidney_not_hcmdb), len(not_hcmdb_not_kidney)] 
              })
contingency.index = ['kidney', 'not_kidney']
contingency

from scipy.stats import fisher_exact
oddsr, p = fisher_exact(contingency, alternative='greater')
print('Oddsr is ', oddsr, ' and p is ', p)
# Out:
# 0             RBL2
# 1            CMAHP
# 2          CARMIL1
# 3             CNBP
# 4            DDX55
#            ...
# 22005      CCDC200
# 22006    LINC00463
# 22007      SUZ12P1
# 22008    LINC02547
# 22009      MIR4722
# Name: 0, Length: 22010, dtype: object
# 1.0
# 22010
# 4216
# 2240
# 1774
# 1.0
#             hcmdb  not_hcmdb
# kidney        478       3738
# not_kidney   1296      16498
# Oddsr is  1.627851924512349  and p is  4.141725963571837e-17

# %%
# checking contingency maths is right
len(hcmdb_in_bg)
478+1296

len(kidney_features)
478+3738

len(kidney_background)
478+3738+1296+16498
# Out:
# 1774
# 1774
# 4216
# 4216
# 22010
# 22010

# %% [markdown]
# ### TFcheckpoint overlap

# %%
# read in TFcheckpoint
import pandas as pd
tfcheck = pd.read_csv('TFCheckpoint_download_180515.txt', sep='\t')
tfcheck = tfcheck['gene_symbol'].drop_duplicates().str.upper()
len(tfcheck)
list(tfcheck)
# Out:
# 3479
# ['ELF5',
#  'TCF7L2',
#  'PLAG1',
#  'NKX2-5',
#  'NRF1',
#  'GATA2',
#  'KLF4',
#  'SPI1',
#  'ESR2',
#  'FOS',
#  'VDR',
#  'HNF1A',
#  'EGR1',
#  'NFATC2',
#  'NHLH1',
#  'SRY',
#  'FOSL1',
#  'FOXA1',
#  'CEBPA',
#  'RELA',
#  'PAX5',
#  'NOBOX',
#  'GATA1',
#  'CEBPB',
#  'HIF1A',
#  'CRX',
#  'CREB1',
#  'FLI1',
#  'SOX5',
#  'FOXC1',
#  'EBF1',
#  'JUN',
#  'NR4A2',
#  'NFYA',
#  'ELF1',
#  'SMAD4',
#  'PAX2',
#  'RUNX2',
#  'FOXP2',
#  'SRF',
#  'SMAD2',
#  'ESR1',
#  'GABPA',
#  'EHF',
#  'BATF',
#  'MEIS1',
#  'TP63',
#  'SOX9',
#  'FOXP1',
#  'INSM1',
#  'MAF',
#  'MYOG',
#  'FOXA2',
#  'NR3C1',
#  'KLF5',
#  'MYC',
#  'FOXH1',
#  'TLX1',
#  'SOX2',
#  'NFE2L2',
#  'NKX3-2',
#  'HNF4A',
#  'SOX10',
#  'ARID3A',
#  'SP1',
#  'USF2',
#  'REST',
#  'SOX17',
#  'CTCF',
#  'ATOH1',
#  'HINFP',
#  'PDX1',
#  'TCF3',
#  'FOXD1',
#  'STAT1',
#  'PAX6',
#  'EGR2',
#  'POU5F1',
#  'PBX1',
#  'IRF1',
#  'NR5A2',
#  'BHLHE40',
#  'MYB',
#  'MYOD1',
#  'JUNB',
#  'E2F4',
#  'BCL6',
#  'TP53',
#  'SREBF1',
#  'HAND1',
#  'MEF2C',
#  'TFAP2A',
#  'PPARG',
#  'NKX3-1',
#  'HOXA5',
#  'BACH1',
#  'PAX4',
#  'TFAP2C',
#  'FOXO1',
#  'NR1H2',
#  'FOXO3',
#  'MEF2A',
#  'YY1',
#  'STAT5B',
#  'HNF1B',
#  'USF1',
#  'SMAD3',
#  'HSF1',
#  'HLTF',
#  'ESRRA',
#  'FOXI1',
#  'MAFB',
#  'NR1H3',
#  'IRF2',
#  'GFI1',
#  'DDIT3',
#  'FOXF2',
#  'STAT3',
#  'GATA4',
#  'T',
#  'GATA3',
#  'TAL1',
#  'MAX',
#  'TCF12',
#  'FOXD3',
#  'EN1',
#  'NFE2L1',
#  'RUNX1',
#  'CDX2',
#  'SREBF2',
#  'RXRA',
#  'AR',
#  'ARNT',
#  'AHR',
#  'NFIL3',
#  'POU2F2',
#  'NFIC',
#  'TEAD1',
#  'PRDM1',
#  'ELK1',
#  'REL',
#  'NFKB1',
#  'PLAGL1',
#  'NFIX',
#  'ARNTL',
#  'FIGLA',
#  'HSF4',
#  'WT1',
#  'BACH2',
#  'NEUROD2',
#  'CUX2',
#  'ASCL1',
#  'ARID5B',
#  'FOXF1',
#  'THRA',
#  'NRL',
#  'FOXK1',
#  'ELK3',
#  'ZBTB7B',
#  'MEF2D',
#  'SOX4',
#  'NFATC3',
#  'MTF1',
#  'CEBPG',
#  'RARG',
#  'ATF4',
#  'ATF5',
#  'ATF3',
#  'ATF7',
#  'FOSB',
#  'DACH1',
#  'DMRT1',
#  'FUBP1',
#  'YBX1',
#  'POU3F1',
#  'ETV2',
#  'ATF2',
#  'NFIA',
#  'VAX2',
#  'HES1',
#  'PPARA',
#  'SOX11',
#  'ETV5',
#  'GATA6',
#  'BARX2',
#  'MITF',
#  'TFAP2E',
#  'MYF6',
#  'CDX1',
#  'E2F7',
#  'SOX8',
#  'PAX3',
#  'SP3',
#  'PAX9',
#  'NFATC4',
#  'CREB3L4',
#  'SMAD1',
#  'TFAP2D',
#  'AIRE',
#  'ZNF350',
#  'MLX',
#  'HHEX',
#  'NEUROG3',
#  'TFE3',
#  'GLI1',
#  'GLI3',
#  'GATA5',
#  'NFE2L3',
#  'GPER1',
#  'NACC2',
#  'EP300',
#  'RAD21',
#  'STAG1',
#  'STAG2',
#  'CHCHD3',
#  'ZNF750',
#  'SOHLH2',
#  'BARHL2',
#  'BHLHE22',
#  'MYOCD',
#  'ARID3C',
#  'DDN',
#  'ZNF217',
#  'MSGN1',
#  'AKNA',
#  'CREBBP',
#  'CDX4',
#  'ZNF746',
#  'HEYL',
#  'CC2D1A',
#  'CC2D1B',
#  'GLIS2',
#  'GLI2',
#  'MEIS3',
#  'PROX1',
#  'FOXC2',
#  'ZFAT',
#  'YBX3',
#  'ZNF639',
#  'FEZF2',
#  'HNRNPK',
#  'ZBTB7A',
#  'HDAC5',
#  'PPARD',
#  'KLF15',
#  'BHLHA15',
#  'BTG2',
#  'SALL1',
#  'SATB1',
#  'POU1F1',
#  'TWIST1',
#  'ZGPAT',
#  'NFIB',
#  'BMPR1A',
#  'ZNF536',
#  'OSR2',
#  'GLIS3',
#  'MKX',
#  'HMGA1',
#  'MYF5',
#  'IFI16',
#  'FUBP3',
#  'BCL11A',
#  'NR5A1',
#  'HOXA7',
#  'ZKSCAN3',
#  'OTX1',
#  'HCFC1',
#  'SUB1',
#  'TARDBP',
#  'RFX6',
#  'LEF1',
#  'PHB',
#  'SARNP',
#  'EPAS1',
#  'CTCFL',
#  'SOX12',
#  'MESP1',
#  'BARHL1',
#  'HES6',
#  'C1ORF85',
#  'HDGF',
#  'HMGA2',
#  'PGR',
#  'CSRNP1',
#  'CSRNP2',
#  'CSRNP3',
#  'PTH',
#  'POU4F2',
#  'PRDM5',
#  'TBX15',
#  'TBX18',
#  'BSX',
#  'OVOL1',
#  'CREB3L2',
#  'MEOX2',
#  'MSX2',
#  'SIX3',
#  'FOXP3',
#  'EBF2',
#  'EBF3',
#  'TFEB',
#  'ARNTL2',
#  'MESP2',
#  'MED1',
#  'SOHLH1',
#  'DLX3',
#  'ONECUT1',
#  'MSX1',
#  'KLF17',
#  'SKIL',
#  'RBPJ',
#  'ZBTB4',
#  'HOXD13',
#  'LMO2',
#  'NR4A1',
#  'HEY1',
#  'E2F8',
#  'RUNX3',
#  'EAF2',
#  'NFATC1',
#  'PLSCR1',
#  'GZF1',
#  'CUX1',
#  'NEUROD1',
#  'ARX',
#  'ZFPM1',
#  'TCF21',
#  'VAX1',
#  'HOXA10',
#  'NKX6-1',
#  'TBX20',
#  'IKZF1',
#  'GRHL3',
#  'TLE4',
#  'PITX2',
#  'PAX7',
#  'MAFA',
#  'OLIG2',
#  'HOXA2',
#  'MYPOP',
#  'JARID2',
#  'FOXJ1',
#  'YLPM1',
#  'BATF3',
#  'ETV4',
#  'PBX3',
#  'POU4F3',
#  'GCM1',
#  'DLX5',
#  'IGHMBP2',
#  'SIX2',
#  'POU3F2',
#  'ISL1',
#  'IRF4',
#  'SOX7',
#  'ESRRG',
#  'CLOCK',
#  'HAND2',
#  'MAZ',
#  'FOXL2',
#  'MEOX1',
#  'KLF11',
#  'SIX4',
#  'DLX2',
#  'HELT',
#  'MLXIPL',
#  'TEF',
#  'FOXP4',
#  'NPAS4',
#  'HSF2',
#  'ZNF219',
#  'SNAI1',
#  'HOXB5',
#  'PURB',
#  'NR2C1',
#  'POU4F1',
#  'RXRB',
#  'ETV1',
#  'KCNH8',
#  'GMEB1',
#  'NR2F6',
#  'BHLHE41',
#  'ETS2',
#  'POU2F3',
#  'NEUROD6',
#  'OTX2',
#  'MXD1',
#  'SOX18',
#  'SIX6',
#  'ZNF467',
#  'NKX2-2',
#  'ZBTB16',
#  'FOXK2',
#  'FERD3L',
#  'BCL11B',
#  'GRHL1',
#  'NKX2-8',
#  'EBF4',
#  'MIXL1',
#  'ZC3H8',
#  'DMBX1',
#  'CREB3L1',
#  'JDP2',
#  'GLIS1',
#  'KLF16',
#  'ONECUT3',
#  'DLX4',
#  'ELF3',
#  'TXK',
#  'CARF',
#  'ASCL3',
#  'NFAT5',
#  'PHOX2B',
#  'ZBTB20',
#  'GSX1',
#  'HOXC13',
#  'TBX3',
#  'RFX4',
#  'TBX5',
#  'NR1H4',
#  'HEY2',
#  'ONECUT2',
#  'GCFC2',
#  'CREB3L3',
#  'PITX3',
#  'TEAD2',
#  'SCRT2',
#  'NR1I2',
#  'TBX1',
#  'TBX2',
#  'ETV7',
#  'NR2E1',
#  'PROP1',
#  'ZIC2',
#  'ZIC3',
#  'ZIC1',
#  'PHOX2A',
#  'STK16',
#  'NR4A3',
#  'PKNOX1',
#  'SOX15',
#  'HES5',
#  'FOXJ2',
#  'SCX',
#  'MYBL2',
#  'MEIS2',
#  'PATZ1',
#  'CGGBP1',
#  'SOX14',
#  'KLF13',
#  'RAX',
#  'ESX1',
#  'SNAI3',
#  'SNAI2',
#  'ETV6',
#  'AEBP1',
#  'FOXE1',
#  'RCOR1',
#  'ZNF281',
#  'NFYC',
#  'IKZF3',
#  'SOX30',
#  'AEBP2',
#  'RXRG',
#  'CEBPE',
#  'HMX1',
#  'PREB',
#  'KCNIP3',
#  'MSC',
#  'KLF12',
#  'KLF9',
#  'ALX4',
#  'SIX1',
#  'TP73',
#  'IRF7',
#  'ALX1',
#  'PLAGL2',
#  'POU3F3',
#  'BCL6B',
#  'HOXC11',
#  'SOX1',
#  'MEF2B',
#  'NR0B1',
#  'CREB3',
#  'MNT',
#  'NR6A1',
#  'MYT1',
#  'TCF4',
#  'ELF4',
#  'HOXD9',
#  'PITX1',
#  'ARNT2',
#  'TEAD4',
#  'ZSCAN21',
#  'NR1D1',
#  'NR2F2',
#  'CEBPD',
#  'ARID3B',
#  'TGIF1',
#  'PCGF6',
#  'CREB5',
#  'NR3C2',
#  'ZNF292',
#  'NFKB2',
#  'ZNF148',
#  'RELB',
#  'NR1I3',
#  'NKX6-2',
#  'MYBL1',
#  'NFX1',
#  'HOXD8',
#  'RARA',
#  'TCF7',
#  'MZF1',
#  'ZFP90',
#  'TFAP2B',
#  'TFAP4',
#  'ATF1',
#  'HIVEP1',
#  'DBP',
#  'XBP1',
#  'PTF1A',
#  'CEBPZ',
#  'E4F1',
#  'RARB',
#  'TFAM',
#  'POU2F1',
#  'NKX2-1',
#  'ARHGAP35',
#  'THRB',
#  'PAX8',
#  'ASCL2',
#  'RFX5',
#  'GFI1B',
#  'ESRRB',
#  'MAFF',
#  'STAT6',
#  'STAT2',
#  'E2F6',
#  'E2F3',
#  'FOSL2',
#  'MAFK',
#  'ZNF143',
#  'ERG',
#  'ZFX',
#  'DUX4',
#  'HOXA9',
#  'E2F1',
#  'MYCN',
#  'ZEB1',
#  'MECOM',
#  'ZBTB33',
#  'MAFG',
#  'ZNF354C',
#  'LHX3',
#  'PRRX2',
#  'STAT5A',
#  'STAT4',
#  'HNF4G',
#  'ETS1',
#  'ZNF263',
#  'SOX3',
#  'ELK4',
#  'SOX6',
#  'SPZ1',
#  'KLF1',
#  'FOXQ1',
#  'SP2',
#  'RFX1',
#  'NR2E3',
#  'SPIB',
#  'NR2C2',
#  'FEV',
#  'RREB1',
#  'NFE2',
#  'RFX2',
#  'HLF',
#  'FOXL1',
#  'NR2F1',
#  'JUND',
#  'THAP1',
#  'TBP',
#  'NFYB',
#  'HOXC9',
#  'BRCA1',
#  'HESX1',
#  'HOXB3',
#  'GSC',
#  'RBPJL',
#  'HOXB9',
#  'TSC22D1',
#  'MXI1',
#  'HOXC6',
#  'ZFP161',
#  'MYNF1',
#  'FOXD4',
#  'HOXB1',
#  'TCF20',
#  'ZNF80',
#  'PRDM2',
#  'MYEF2',
#  'ATF6',
#  'ZNF652',
#  'ZNF274',
#  'ZNRD1',
#  'ZNF674',
#  'DMRT2',
#  'OTP',
#  'CNOT3',
#  'ZNF429',
#  'CREM',
#  'ZNF395',
#  'DBX1',
#  'HES4',
#  'GBX1',
#  'SP7',
#  'ZNF35',
#  'OVOL2',
#  'IRF8',
#  'HNRNPAB',
#  'ZNF224',
#  'PAX1',
#  'HOXB4',
#  'ZNF589',
#  'SIM2',
#  'HOXB8',
#  'VEZF1',
#  'HOXD10',
#  'HOXC8',
#  'GMEB2',
#  'ZNF76',
#  'ZNF10',
#  'ZNF202',
#  'FOXB1',
#  'ZHX2',
#  'ZNF804A',
#  'PHF20',
#  'CASZ1',
#  'BHLHA9',
#  'ZNF238',
#  'LZTFL1',
#  'ZNF302',
#  'CAMTA1',
#  'HMBOX1',
#  'ZNF580',
#  'HOXA13',
#  'IRF6',
#  'CREBL2',
#  'ZBTB1',
#  'HOXC5',
#  'ZNF512B',
#  'ZNF592',
#  'ZNF687',
#  'ZMYND8',
#  'POU3F4',
#  'KLF2',
#  'HIF3A',
#  'RORC',
#  'EN2',
#  'SALL2',
#  'VENTX',
#  'CTBP2',
#  'ZBTB42',
#  'HIVEP3',
#  'PRDM14',
#  'ZNF431',
#  'TOX3',
#  'BTBD11',
#  'GRHL2',
#  'NKX1-2',
#  'SON',
#  'SHOX2',
#  'ZNF513',
#  'ZNF821',
#  'RAI1',
#  'ZNF673',
#  'ZNF41',
#  'TFCP2L1',
#  'FOXD4L1',
#  'ZFP1',
#  'ZFP54',
#  'ZNF300',
#  'PHF10',
#  'ZNF193',
#  'IRX1',
#  'PHF7',
#  'NFKBIZ',
#  'ZNF711',
#  'ZNF250',
#  'ZNF251',
#  'ZNF252P',
#  'ZNF34',
#  'ZNF517',
#  'ZNF7',
#  'ZNF131',
#  'IKZF2',
#  'TBX10',
#  'FAM170A',
#  'IRF9',
#  'FOXD4L5',
#  'FOXD4L6',
#  'HMGB1P1',
#  'RHOXF2B',
#  'ZNF705D',
#  'ZNF705F',
#  'ZNF720',
#  'ZNF734P',
#  'ZNF98',
#  'DBX2',
#  'RNF112',
#  'ZFY',
#  'HLX',
#  'SATB2',
#  'FOXA3',
#  'DMTF1',
#  'TSHZ2',
#  'TSHZ3',
#  'ZSCAN10',
#  'LBX1',
#  'DRGX',
#  'MYRF',
#  'LHX6',
#  'IER2',
#  'ZNF642',
#  'ZNF69',
#  'ZBTB5',
#  'OSR1',
#  'ZBTB2',
#  'PBX2',
#  'FEZF1',
#  'EWSR1',
#  'BTBD3',
#  'IRX6',
#  'SALL3',
#  'ZNF84',
#  'MACC1',
#  'OLIG3',
#  'KLF14',
#  'SP6',
#  'KHSRP',
#  'PRDM12',
#  'PRDM13',
#  'PRDM16',
#  'THAP11',
#  'MN1',
#  'ST18',
#  'RFX7',
#  'KLF6',
#  'NKX6-3',
#  'CTNNBL1',
#  'FOXS1',
#  'RHOX5',
#  'OLIG1',
#  'ZNF256',
#  'BCLAF1',
#  'ZNF133',
#  'FOXJ3',
#  'FOXN2',
#  'FOXN3',
#  'FOXR1',
#  'FOXR2',
#  'FOXG1',
#  'PBX4',
#  'TSHZ1',
#  'ZSCAN4',
#  'SP8',
#  'SP110',
#  'ZNF124',
#  'DLX1',
#  'SIX5',
#  'ZFHX3',
#  'ZBED1',
#  'EGR4',
#  'ZNF175',
#  'ZNF23',
#  'ZNF692',
#  'ISL2',
#  'SP5',
#  'DACH2',
#  'FOXN4',
#  'TFDP3',
#  'ZHX3',
#  'ZNF433',
#  'CREBRF',
#  'BNC1',
#  'ZNF384',
#  'TULP4',
#  'SALL4',
#  'ZNF284',
#  'EMX1',
#  'EMX2',
#  'CIC',
#  'NANOG',
#  'ZNF492',
#  'RNF2',
#  'ZBTB45',
#  'PRDM15',
#  'ZSCAN12',
#  'SCML4',
#  'FOXI2',
#  'IRX5',
#  'IRX3',
#  'NANOGP8',
#  'ZNF468',
#  'ZNF267',
#  'LHX4',
#  'UBP1',
#  'FOXO6',
#  'TBX6',
#  'BARX1',
#  'AFR2',
#  'TBPL1',
#  'ZNF18',
#  'NKX2-6',
#  'VSX2',
#  'ZNF295',
#  'ZNF333',
#  'TCFL5',
#  'LHX9',
#  'PHF6',
#  'ZNF322',
#  'ZNF668',
#  'NRG1',
#  'FOXD4L3',
#  'NHLH2',
#  'ZIC4',
#  'ZIC5',
#  'BHLHE23',
#  'SP9',
#  'NPAS1',
#  'NPAS3',
#  'ZNF367',
#  'NEUROG2',
#  'ZNF470',
#  'HOXB2',
#  'HOXB6',
#  'SP4',
#  'HOXC4',
#  'TFCP2',
#  'HIC1',
#  'ALX3',
#  'SUZ12',
#  'ZNF496',
#  'IRX2',
#  'HOXB13',
#  'KLF10',
#  'YY2',
#  'BNC2',
#  'RAX2',
#  'HBP1',
#  'ATF6B',
#  'DPF3',
#  'TOX2',
#  'HOXD3',
#  'LRRFIP1',
#  'ZKSCAN5',
#  'ZNF214',
#  'ZNF215',
#  'ZNF22',
#  'NEUROD4',
#  'HOMEZ',
#  'FOXE3',
#  'RNF141',
#  'ZNF230',
#  'MYCL1',
#  'SPIC',
#  'LITAF',
#  'FOXD2',
#  'IRF5',
#  'LCORL',
#  'ZNF43',
#  'ERF',
#  'NR1H5P',
#  'RHOXF2',
#  'KMT2A',
#  'SOX21',
#  'ZNF8',
#  'FOXB2',
#  'PRDM10',
#  'ZNF323',
#  'FAM48A',
#  'ZNF304',
#  'ETV3',
#  'PKNOX2',
#  'LMX1B',
#  'SIM1',
#  'FOXO4',
#  'HOXD1',
#  'SHOX',
#  'DLX6',
#  'ZNF317',
#  'BBX',
#  'EOMES',
#  'HIC2',
#  'ZNF177',
#  'ZNF24',
#  'SMAD5',
#  'ZNF140',
#  'ZNF91',
#  'NPAS2',
#  'ZEB2',
#  'ZNF268',
#  'TBX19',
#  'TRPS1',
#  'ZNF239',
#  'SCRT1',
#  'HES7',
#  'ATOH7',
#  'PEG3',
#  'ZNF382',
#  'SMAD6',
#  'CDC5L',
#  'DPF1',
#  'MLXIP',
#  'BRIP1',
#  'TBX22',
#  'C1ORF61',
#  'IKZF5',
#  'TBX4',
#  'NACC1',
#  'TLX2',
#  'HES3',
#  'HOXC10',
#  'NEUROG1',
#  'ZNF326',
#  'NKX2-3',
#  'HMG20A',
#  'E2F2',
#  'TBX21',
#  'KLF8',
#  'TBR1',
#  'GBX2',
#  'LHX1',
#  'SPDEF',
#  'MGA',
#  'TULP1',
#  'TULP2',
#  'KLF3',
#  'NKRF',
#  'PRDM4',
#  'ZNF157',
#  'PGS1',
#  'DIDO1',
#  'ZFAND3',
#  'RFX3',
#  'HIVEP2',
#  'HMX3',
#  'SOX13',
#  'ZBTB10',
#  'PARP1',
#  'DEAF1',
#  'ZNF85',
#  'ZNF205',
#  'ZNF423',
#  'KLF7',
#  'DUX1',
#  'HOXA1',
#  'TGFB1I1',
#  'GSC2',
#  'IRF3',
#  'ZNF189',
#  'ZFP37',
#  'ZNF45',
#  'ZFP42',
#  'HR',
#  'HTATIP2',
#  'LMX1A',
#  'ZBTB17',
#  'HOXA6',
#  'EED',
#  'FOXM1',
#  'FOXN1',
#  'HOXA11',
#  'TCF15',
#  'ELF2',
#  'HOXB7',
#  'MEF2BNB-MEF2B',
#  'ARID5A',
#  'POU6F1',
#  'MYT1L',
#  'POU6F2',
#  'TGIF2LX',
#  'MXD3',
#  'MXD4',
#  'NFXL1',
#  'ZNF37A',
#  'TFDP1',
#  'ZNF354A',
#  'HES2',
#  'TFEC',
#  'HOXA3',
#  'RORB',
#  'RORA',
#  'HOXA4',
#  'NR1D2',
#  'MTF2',
#  'E2F5',
#  'TFDP2',
#  'CNBP',
#  ...]

# %%
# read in kidney genes
kidney_features = pd.read_csv('../figs_xgboost/xgboost_models/features_mapped_to_genes.csv', header=None)[0]
kidney_features = kidney_features.str.upper().drop_duplicates()
kidney_features
# Out:
# 0            RBL2
# 1           DDX55
# 2           LRFN1
# 3          TAS1R3
# 4         CCDC181
#           ...
# 4211       CSNK1D
# 4212    LINC00942
# 4213        SNX33
# 4214         IMP3
# 4215        DAND5
# Name: 0, Length: 4216, dtype: object

# %%
# get overlapping genes

tfcheck_overlap = tfcheck[tfcheck.isin(kidney_features)]
tfcheck_overlap

len(tfcheck_overlap)
len(tfcheck_overlap)/len(tfcheck) # 20% of tfcheck genes
len(tfcheck_overlap)/len(kidney_features) # 16% of kidney genes
# Out:
# 0         ELF5
# 1       TCF7L2
# 5        GATA2
# 8         ESR2
# 14       NHLH1
#          ...
# 3462     ZMYM4
# 3463     ZMYM5
# 3469    ZSWIM4
# 3473      ZHX1
# 3476      ZXDC
# Name: gene_symbol, Length: 701, dtype: object
# 701
# 0.20149468237999424
# 0.16627134724857684

# %%
# now lets do a fishers test

# for this, we need the kidney gene background
kidney_background = pd.read_csv('../figs_xgboost/xgboost_models/input_features_for_background_gene_list_symbols.csv', header=None)[0]
kidney_background = kidney_background.str.upper()
kidney_background


# now lets make the 2x2 contingency matrix

kidney_features.isin(kidney_background).mean() # check, should be 1

len(kidney_background)
len(kidney_features)

len(tfcheck)

tfcheck_in_bg = tfcheck[tfcheck.isin(kidney_background)] # need just parts of cosmic that are in background
len(tfcheck_in_bg)

tfcheck_overlap.isin(kidney_background).mean() # should be 1


import numpy as np
tfcheck_not_kidney = tfcheck_in_bg[np.logical_not(tfcheck_in_bg.isin(kidney_features))]

kidney_not_tfcheck = kidney_features[np.logical_not(kidney_features.isin(tfcheck_in_bg))]

not_tfcheck_not_kidney = kidney_background[np.logical_not((kidney_background.isin(tfcheck_in_bg)) | (kidney_background.isin(kidney_features)))]


contingency = pd.DataFrame({
                'tfcheck': [len(tfcheck_overlap), len(tfcheck_not_kidney)], 
                'not_tfcheck': [len(kidney_not_tfcheck), len(not_tfcheck_not_kidney)] 
              })
contingency.index = ['kidney', 'not_kidney']
contingency

from scipy.stats import fisher_exact
oddsr, p = fisher_exact(contingency, alternative='greater')
print('Oddsr is ', oddsr, ' and p is ', p)
# Out:
# 0             RBL2
# 1            CMAHP
# 2          CARMIL1
# 3             CNBP
# 4            DDX55
#            ...
# 22005      CCDC200
# 22006    LINC00463
# 22007      SUZ12P1
# 22008    LINC02547
# 22009      MIR4722
# Name: 0, Length: 22010, dtype: object
# 1.0
# 22010
# 4216
# 3479
# 2840
# 1.0
#             tfcheck  not_tfcheck
# kidney          701         3515
# not_kidney     2139        15655
# Oddsr is  1.4596037685282537  and p is  3.583681364893711e-15

# %%
# checking contingency maths is right
len(tfcheck_in_bg)
701+2139

len(kidney_features)
701+3515

len(kidney_background)
701+2139+3515+15655
# Out:
# 2840
# 2840
# 4216
# 4216
# 22010
# 22010

# %% [markdown]
# ### Turajlic overlap

# %%
# read in Turajlic
import pandas as pd
turajlic = pd.read_csv('Turajlic 2018 list RCC driver genes.csv')
turajlic = turajlic['TARGET'].append(turajlic['ALLIAS']).append(turajlic['ALLIAS.1']).dropna()
turajlic = turajlic.str.split(';').explode().str.strip() # when multiple aliases are on the same line, split up
turajlic = turajlic.str.upper().drop_duplicates()
list(turajlic)
# Out:
# ['VHL',
#  'PBRM1',
#  'SETD2',
#  'BAP1',
#  'KDM5C',
#  'MTOR',
#  'CSMD3',
#  'TP53',
#  'PTEN',
#  'PIK3CA',
#  'DNHD1',
#  'ATM',
#  'ARID1A',
#  'FMN2',
#  'SMARCA4',
#  'TET2',
#  'FBN2',
#  'NAV3',
#  'KEAP1',
#  'M6PR',
#  'MET',
#  'KMT2C',
#  'TCEB1',
#  'TNF',
#  'RHEB',
#  'TSC1',
#  'LRRK2',
#  'TSC2',
#  'STK11',
#  'NF2',
#  'KMT2D',
#  'TNFRSF14',
#  'MACF1',
#  'COL11A1',
#  'OLFML3',
#  'VTCN1',
#  'RFX5',
#  'TCHH',
#  'SPTA1',
#  'TNFSF18',
#  'TNFSF4',
#  'SMG7',
#  'HMCN1',
#  'PTGS2',
#  'IL10',
#  'USH2A',
#  'OBSCN',
#  'SPTBN1',
#  'VWA3B',
#  'LRP2',
#  'ADAM23',
#  'OBSL1',
#  'SPHKAP',
#  'KIAA2018',
#  'CD80',
#  'CD86',
#  'SI',
#  'WDFY3',
#  'FAT1',
#  'TRIO',
#  'FYB1',
#  'MAST4',
#  'FAT2',
#  'FLT4',
#  'ZNF451',
#  'MDN1',
#  'CCNC',
#  'SYNE1',
#  'RADIL',
#  'IL6',
#  'ABCA13',
#  'PCLO',
#  'AKAP9',
#  'TRRAP',
#  'MUC17',
#  'ZNF800',
#  'MGAM',
#  'ZFHX4',
#  'PKHD1L1',
#  'PLEC',
#  'CD274',
#  'PDCD1LG2',
#  'FREM1',
#  'CDKN2B',
#  'TRPM3',
#  'ROR2',
#  'TGFBR1',
#  'ABCA1',
#  'CUBN',
#  'PLCE1',
#  'MUC5B',
#  'PAMR1',
#  'TENM4',
#  'FAT3',
#  'CEP295',
#  'NFRKB',
#  'CD27',
#  'CD4',
#  'YBX3',
#  'SMARCC2',
#  'LRP1',
#  'GCN1L1',
#  'DNAH10',
#  'CCDC168',
#  'TGFB3',
#  'TLN2',
#  'CD276',
#  'ANPEP',
#  'DNAH3',
#  'CNOT1',
#  'ZNF469',
#  'DNAH2',
#  'STAT5B',
#  'STAT3',
#  'TBX21',
#  'SDK2',
#  'DNAH17',
#  'PIEZO2',
#  'CD70',
#  'MUC16',
#  'CPAMD8',
#  'TSHZ3',
#  'TGFB1',
#  'CD40',
#  'IL10RB',
#  'MED12',
#  'MEGF6',
#  'FPGT',
#  'TXNIP',
#  'TPM3',
#  'CR1',
#  'MSGN1',
#  'C2ORF44',
#  'ALK',
#  'EML4',
#  'LMAN2L',
#  'LRP1B',
#  'NFE2L2',
#  'ZNF804A',
#  'RPL14',
#  'TFG',
#  'SOX2',
#  'ABCC5',
#  'MUC4',
#  'FGFR3',
#  'SLC34A2',
#  'KDR',
#  'CLOCK',
#  'NPNT',
#  'GALNT7',
#  'NNT',
#  'CD74',
#  'LARP1',
#  'BTNL3',
#  'HIVEP1',
#  'CUL7',
#  'YIPF3',
#  'ROS1',
#  'EZR',
#  'CARD11',
#  'EGFR',
#  'ASB15',
#  'BRAF',
#  'MSR1',
#  'WHSC1L1',
#  'PITRM1',
#  'MLLT10',
#  'KIF5B',
#  'RET',
#  'CCDC6',
#  'KCNMA1',
#  'FGFR2',
#  'OR4C13',
#  'FAM111B',
#  'AHNAK',
#  'LRIG3',
#  'EBPL',
#  'SLITRK6',
#  'RALGAPA1',
#  'NKX2-1',
#  'AP5M1',
#  'MUDENG',
#  'SYNE2',
#  'AKT1',
#  'TP53BP1',
#  'CCNB2',
#  'MAP2K1',
#  'AKAP13',
#  'VMO1',
#  'MYH3',
#  'NF1',
#  'ERBB2',
#  'GRB7',
#  'KRT32',
#  'CLTC',
#  'MAP2K2',
#  'KANK3',
#  'ZNF536',
#  'RYR1',
#  'SPTBN4',
#  'SHANK1',
#  'NLRP12',
#  'SDC4',
#  'KDM6A',
#  'STAG2',
#  'SDHB',
#  'SDHC',
#  'FH',
#  'SDHD',
#  'ELOC',
#  'USF3',
#  'FYN BINDING PROTEIN 1',
#  'FYB',
#  'ADAP',
#  'THC3',
#  'PRO0823',
#  'SLAP130',
#  'SLAP-130',
#  'GCN1L',
#  'PRIC295',
#  'WDCP',
#  'NSD3',
#  'KMT3F',
#  'KMT3G',
#  'WHISTLE',
#  'PP14328',
#  'MU5',
#  'MUD',
#  'C14ORF108',
#  'GCN1']

# %%
# read in kidney genes
kidney_features = pd.read_csv('../figs_xgboost/xgboost_models/features_mapped_to_genes.csv', header=None)[0]
kidney_features = kidney_features.str.upper()
kidney_features
# Out:
# 0            RBL2
# 1           DDX55
# 2           LRFN1
# 3          TAS1R3
# 4         CCDC181
#           ...
# 4211       CSNK1D
# 4212    LINC00942
# 4213        SNX33
# 4214         IMP3
# 4215        DAND5
# Name: 0, Length: 4216, dtype: object

# %%
# get overlapping genes

turajlic_overlap = turajlic[turajlic.isin(kidney_features)]
turajlic_overlap

len(turajlic_overlap)
len(turajlic_overlap)/len(turajlic) # 25% of turajlic genes
len(turajlic_overlap)/len(kidney_features) # 1.3% of kidney genes
# Out:
# 5         MTOR
# 7         TP53
# 10       DNHD1
# 14     SMARCA4
# 16        FBN2
# 20         MET
# 24        RHEB
# 27        TSC2
# 28       STK11
# 30       KMT2D
# 32       MACF1
# 33     COL11A1
# 37        TCHH
# 41        SMG7
# 43       PTGS2
# 46       OBSCN
# 47      SPTBN1
# 51       OBSL1
# 52      SPHKAP
# 54        CD80
# 55        CD86
# 58        FAT1
# 61       MAST4
# 63        FLT4
# 68       RADIL
# 73       TRRAP
# 79        PLEC
# 85        ROR2
# 90       MUC5B
# 92       TENM4
# 100       LRP1
# 109      CNOT1
# 110     ZNF469
# 113      STAT3
# 116     DNAH17
# 121      TSHZ3
# 122      TGFB1
# 126      MEGF6
# 129       TPM3
# 133        ALK
# 134       EML4
# 136      LRP1B
# 144      FGFR3
# 150        NNT
# 154     HIVEP1
# 155       CUL7
# 158        EZR
# 165     PITRM1
# 170     KCNMA1
# 180      AP5M1
# 182      SYNE2
# 184    TP53BP1
# 187     AKAP13
# 188       VMO1
# 190        NF1
# 191      ERBB2
# 194       CLTC
# 198       RYR1
# 199     SPTBN4
# dtype: object
# 59
# 0.2565217391304348
# 0.013994307400379507

# %%
# now lets do a fishers test

# for this, we need the kidney gene background
kidney_background = pd.read_csv('../figs_xgboost/xgboost_models/input_features_for_background_gene_list_symbols.csv', header=None)[0]
kidney_background = kidney_background.str.upper()
kidney_background


# now lets make the 2x2 contingency matrix

kidney_features.isin(kidney_background).mean() # check, should be 1

len(kidney_background)
len(kidney_features)

len(turajlic)

turajlic_in_bg = turajlic[turajlic.isin(kidney_background)] # need just parts of cosmic that are in background
len(turajlic_in_bg)

turajlic_overlap.isin(kidney_background).mean() # should be 1


import numpy as np
turajlic_not_kidney = turajlic_in_bg[np.logical_not(turajlic_in_bg.isin(kidney_features))]

kidney_not_turajlic = kidney_features[np.logical_not(kidney_features.isin(turajlic_in_bg))]

not_turajlic_not_kidney = kidney_background[np.logical_not((kidney_background.isin(turajlic_in_bg)) | (kidney_background.isin(kidney_features)))]


contingency = pd.DataFrame({
                'turajlic': [len(turajlic_overlap), len(turajlic_not_kidney)], 
                'not_turajlic': [len(kidney_not_turajlic), len(not_turajlic_not_kidney)] 
              })
contingency.index = ['kidney', 'not_kidney']
contingency

from scipy.stats import fisher_exact
oddsr, p = fisher_exact(contingency, alternative='greater')
print('Oddsr is ', oddsr, ' and p is ', p)
# Out:
# 0             RBL2
# 1            CMAHP
# 2          CARMIL1
# 3             CNBP
# 4            DDX55
#            ...
# 22005      CCDC200
# 22006    LINC00463
# 22007      SUZ12P1
# 22008    LINC02547
# 22009      MIR4722
# Name: 0, Length: 22010, dtype: object
# 1.0
# 22010
# 4216
# 230
# 194
# 1.0
#             turajlic  not_turajlic
# kidney            59          4157
# not_kidney       135         17659
# Oddsr is  1.85654006183234  and p is  0.00010658052305057398

# %%
# checking contingency maths is right
len(turajlic_in_bg)
59+135

len(kidney_features)
59+4157

len(kidney_background)
59+4157+135+17659
# Out:
# 194
# 194
# 4216
# 4216
# 22010
# 22010

# %%
### Turajlic overlap


# read in Turajlic
import pandas as pd
turajlic = pd.read_csv('Turajlic 2018 list RCC driver genes.csv')
turajlic = turajlic['TARGET'].append(turajlic['ALLIAS']).append(turajlic['ALLIAS.1']).dropna()
turajlic = turajlic.str.split(';').explode().str.strip() # when multiple aliases are on the same line, split up
turajlic = turajlic.str.upper().drop_duplicates()
list(turajlic)

# read in kidney genes
kidney_features = pd.read_csv('../figs_xgboost/xgboost_models/features_mapped_to_genes.csv', header=None)[0]
kidney_features = kidney_features.str.upper()
kidney_features


# get overlapping genes

turajlic_overlap = turajlic[turajlic.isin(kidney_features)]
turajlic_overlap

len(turajlic_overlap)
len(turajlic_overlap)/len(turajlic) # 25% of turajlic genes
len(turajlic_overlap)/len(kidney_features) # 1.3% of kidney genes




# now lets do a fishers test

# for this, we need the kidney gene background
kidney_background = pd.read_csv('../figs_xgboost/xgboost_models/input_features_for_background_gene_list_symbols.csv', header=None)[0]
kidney_background = kidney_background.str.upper()
kidney_background


# now lets make the 2x2 contingency matrix

kidney_features.isin(kidney_background).mean() # check, should be 1

len(kidney_background)
len(kidney_features)

len(turajlic)

turajlic_in_bg = turajlic[turajlic.isin(kidney_background)] # need just parts of cosmic that are in background
len(turajlic_in_bg)

turajlic_overlap.isin(kidney_background).mean() # should be 1


import numpy as np
turajlic_not_kidney = turajlic_in_bg[np.logical_not(turajlic_in_bg.isin(kidney_features))]

kidney_not_turajlic = kidney_features[np.logical_not(kidney_features.isin(turajlic_in_bg))]

not_turajlic_not_kidney = kidney_background[np.logical_not((kidney_background.isin(turajlic_in_bg)) | (kidney_background.isin(kidney_features)))]


contingency = pd.DataFrame({
                'turajlic': [len(turajlic_overlap), len(turajlic_not_kidney)], 
                'not_turajlic': [len(kidney_not_turajlic), len(not_turajlic_not_kidney)] 
              })
contingency.index = ['kidney', 'not_kidney']
contingency

from scipy.stats import fisher_exact
oddsr, p = fisher_exact(contingency, alternative='greater')
print('Oddsr is ', oddsr, ' and p is ', p)



# checking contingency maths is right
len(turajlic_in_bg)
59+135

len(kidney_features)
59+4157

len(kidney_background)
59+4157+135+17659

# %% [markdown]
# # Testing out four more gene lists

# %%
# read in genelist
import pandas as pd
def read_genelist(path):    

    if 'EpiFactor DB.csv' in path:
        genelist = pd.read_csv(path)
        genelist = genelist['HGNC_symbol'].drop_duplicates().str.upper()
        
    if 'KEGG_hsa05211' in path:
        genelist = pd.read_csv(path, header=None)
        genelist = genelist[0].drop_duplicates().str.upper()
        
    if 'pRCC -harmonizome' in path:
        genelist = pd.read_csv(path)
        genelist = genelist['Symbol'].drop_duplicates().str.upper()
        
    if 'RCC harmonizome' in path:
        genelist = pd.read_csv(path)
        genelist = genelist['symbol'].drop_duplicates().str.upper()
        
    print(len(genelist))
    print(list(genelist))
    return(genelist)
    
genelist = read_genelist('Gene Lists - RCC harmonizome -diseases db.csv')
# Out:
# 829
# ['IL2', 'VHL', 'MTOR', 'TFE3', 'CA9', 'IFNA1', 'PRCC', 'FLCN', 'FH', 'KRT7', 'ZNF135', 'DIRC2', 'VEGFA', 'PDPN', 'HIF1A', 'AMACR', 'SRMS', 'CDH6', 'TFEB', 'PBRM1', 'IFNA2', 'PAX8', 'CDH16', 'PAX2', 'TP53', 'MET', 'TSC2', 'TCEB1', 'CUL2', 'TCEB2', 'TPX2', 'EPAS1', 'SETD2', 'CD4', 'CDH1', 'AKT1', 'FLT1', 'EGFR', 'CD34', 'CRP', 'CSF2', 'CD70', 'NCAM1', 'PTEN', 'TPBG', 'MLANA', 'FHIT', 'PCNA', 'IL6', 'ASPSCR1', 'CCND1', 'FGF2', 'HLA-A', 'ABCB1', 'RBX1', 'CD6', 'KRT20', 'S100A1', 'HLA-B', 'TNFSF10', 'RNF139', 'B3GAT1', 'SMUG1', 'ALPP', 'ARPP21', 'ALPPL2', 'ALPL', 'MMP2', 'TNF', 'KDR', 'CLDN8', 'IFNA10', 'EGLN3', 'IL21', 'SDHB', 'PDGFRB', 'HBA1', 'WT1', 'MITF', 'HLA-C', 'PVALB', 'MIR210', 'HBA2', 'KDM5C', 'PARK2', 'TYMP', 'BIRC5', 'RASSF1', 'PTHLH', 'MMP9', 'CA12', 'SLC2A1', 'ZHX2', 'CD44', 'NNMT', 'COL18A1', 'PLIN2', 'SCHIP1', 'IFNA21', 'TGFB1', 'ENO2', 'IL4', 'KANK1', 'HAVCR1', 'ERBB2', 'JADE1', 'IFNA17', 'MUC1', 'LRCH4', 'FLT3', 'CD80', 'CTLA4', 'CD83', 'BAP1', 'SPAG4', 'B2M', 'FASLG', 'SDHC', 'STAT3', 'CD68', 'LRRC2', 'FOXP3', 'KANK4', 'EIF4EBP1', 'CASP3', 'MAGEA9', 'MAGEA9B', 'SRC', 'ICAM1', 'SYP', 'CALB2', 'FN1', 'KDM6A', 'SYCN', 'NKX2-1', 'MAGEA6', 'MIR21', 'TSC1', 'TG', 'GJB1', 'ANXA2', 'ABHD14A', 'BAX', 'AQP1', 'NAPSA', 'HIVEP3', 'ROS1', 'KRT8', 'MKI67', 'SFRP1', 'VCL', 'SDHD', 'CXCL12', 'RET', 'PTPRG', 'CDH2', 'NONO', 'SPINT2', 'LLGL1', 'HLA-G', 'ZNF77', 'CHGA', 'CDKN1A', 'CLTC', 'MSLN', 'TAP1', 'MT1G', 'SMARCB1', 'SDHA', 'TFCP2L1', 'PITX1', 'NDRG2', 'HGF', 'EGLN2', 'CLDN7', 'HEPACAM', 'CORO6', 'KANK3', 'ZNF600', 'AMMECR1L', 'ACOT6', 'TMEM213', 'INO80D', 'MDM2', 'SIGLEC7', 'FBXO47', 'POLR2A', 'C4ORF46', 'LCK', 'PDGFRA', 'ALB', 'RNF112', 'LRRC3B', 'GSTA3', 'GSTA2', 'GSTA4', 'PKM', 'PRAME', 'PTGS2', 'FABP7', 'GSTA1', 'TGFBR2', 'TCF21', 'CDCP1', 'EZH2', 'FUT4', 'CAV1', 'ALK', 'GSTP1', 'CASP8', 'CXCR4', 'UPK3A', 'RCC2', 'SLC17A5', 'DDX23', 'FER', 'VIM', 'RPLP0', 'KISS1', 'F8', 'CTSK', 'GNG4', 'ZFP3', 'CXCR3', 'CD86', 'TMSB4XP8', 'IL1B', 'ABCG2', 'AFP', 'IFNAR2', 'CASP9', 'FTL', 'CDKN1B', 'ANXA4', 'HDAC9', 'MGP', 'KRT5', 'VBP1', 'VEGFC', 'BCL2', 'TCEB3', 'HNF4A', 'KLF8', 'FNIP1', 'SECTM1', 'LAP3', 'IL2RA', 'KIT', 'CD69', 'FGF1', 'TRAF3', 'DLL4', 'EFHD1', 'FOLH1', 'HIF1AN', 'DNTT', 'FTH1', 'CCNB1', 'IL36RN', 'KANK2', 'LIMCH1', 'ATP6V1G3', 'KRT34', 'RALYL', 'LMAN2', 'BSG', 'RGS5', 'IGFBP3', 'HRAS', 'FAM107A', 'HIST2H3PS2', 'FADS1', 'PLAU', 'H3F3B', 'H3F3A', 'KISS1R', 'REN', 'PTH', 'FZR1', 'DKK3', 'HNF1B', 'KAAG1', 'RNF185', 'GAL3ST1', 'ANPEP', 'CDKN2A', 'SKP2', 'KLHL35', 'TIMP1', 'INHA', 'PRF1', 'CXXC4', 'LGALS3', 'RPS6KB1', 'MIR10B', 'ITPR2', 'SMARCA2', 'STC2', 'ZNF419', 'MMP7', 'SPP1', 'BNIP3', 'STAT1', 'IFNB1', 'CXCL9', 'LGALS1', 'KHK', 'PGR', 'CD82', 'GGT1', 'CMTM8', 'L1CAM', 'BCL2L1', 'GSN', 'EN2', 'THRB', 'TNS1', 'SEMA5B', 'TMC5', 'JUN', 'IGF1', 'TNS3', 'FLT4', 'FUT11', 'UBE2QL1', 'TIMP2', 'EPOR', 'TTYH2', 'CXCL8', 'STK10', 'TXLNA', 'PTGER4', 'IGF1R', 'LUC7L3', 'TMED6', 'TYMS', 'PTER', 'SSH3', 'APAF1', 'IFNA8', 'GATA3', 'RELA', 'RAP1GAP', 'ZNF773', 'ITGAM', 'ACTL8', 'RHEBL1', 'RPS9', 'UQCR11', 'ELAVL1', 'KRT19', 'EPHA2', 'VASH1', 'NOTCH1', 'ZNF410', 'PNCK', 'AXL', 'ARID1A', 'SETD3', 'GSTM1', 'SLC35G2', 'DNAJB8', 'PPIA', 'CXCL10', 'DUSP9', 'ESR1', 'ABCC3', 'ANKRD11', 'CACNG7', 'MAD2L2', 'ORAI3', 'NCR1', 'MIB1', 'ZNRD1', 'CCDC8', 'IL7', 'NKX1-1', 'PSMB11', 'NKIRAS1', 'NDUFS7', 'CDK2', 'ANTXR1', 'DKK2', 'MIR145', 'TMEM74', 'LDHA', 'CD40', 'LOX', 'KLK3', 'NUP54', 'IL26', 'SSH2', 'SLFN5', 'GATA5', 'SPINK7', 'PXN', 'IL13', 'RPTOR', 'CCND3', 'FGFR1', 'THBS1', 'GSTT1', 'GSTTP1', 'ETNPPL', 'LRIG1', 'BPHL', 'CD247', 'DNMT1', 'TRIM8', 'KMT2B', 'GBP4', 'ZSCAN18', 'FSCN1', 'LAMA4', 'ANGPT2', 'LATS1', 'C11ORF54', 'PARD3', 'ANXA5', 'CDH11', 'PMEL', 'FGF5', 'TRIM9', 'TOP1', 'ORC2', 'SYNGR3', 'EBNA1BP2', 'VDR', 'TBC1D8', 'RARB', 'FUBP3', 'ESM1', 'CRABP2', 'FAM92A1', 'JAK3', 'JAK1', 'TERT', 'CUL1', 'CXCL5', 'CD27', 'IGF2', 'TEAD3', 'MICA', 'MSL2', 'ZEB2', 'CYP1A1', 'CSF1R', 'ACTG1', 'PCDH8', 'CMTM3', 'ZNF346', 'LEFTY1', 'ANGPT1', 'MAL2', 'CX ...

# %%
# read in kidney genes
def read_in_kidney():
    kidney_features = pd.read_csv('../figs_xgboost/xgboost_models/features_mapped_to_genes.csv', header=None)[0]
    kidney_features = kidney_features.str.upper()
    return(kidney_features)

kidney_features = read_in_kidney()
kidney_features
# Out:
# 0            RBL2
# 1           DDX55
# 2           LRFN1
# 3          TAS1R3
# 4         CCDC181
#           ...
# 4211       CSNK1D
# 4212    LINC00942
# 4213        SNX33
# 4214         IMP3
# 4215        DAND5
# Name: 0, Length: 4216, dtype: object

# %%
# get overlapping genes
def get_overlap(genelist, kidney_features):
    genelist_overlap = genelist[genelist.isin(kidney_features)]
    print(genelist_overlap)

    print(len(genelist_overlap))
    print(len(genelist_overlap)/len(genelist))
    print(len(genelist_overlap)/len(kidney_features))
    return(genelist_overlap)

genelist_overlap = get_overlap(genelist, kidney_features)
# Out:
# 2        ACTB
# 9        ADNP
# 11      AICDA
# 15     ANP32A
# 17     ANP32E
#         ...
# 710    ZNF217
# 711    ZNF516
# 712    ZNF532
# 715    ZNF687
# 718    ZRANB3
# Name: HGNC_symbol, Length: 147, dtype: object
# 147
# 0.20416666666666666
# 0.03486717267552182

# %%
# now lets do a fishers test

def fishers(genelist, genelist_overlap, kidney_features):
    # for this, we need the kidney gene background
    kidney_background = pd.read_csv('../figs_xgboost/xgboost_models/input_features_for_background_gene_list_symbols.csv', header=None)[0]
    kidney_background = kidney_background.str.upper()

    # now lets make the 2x2 contingency matrix
    print('Should be 1: ', kidney_features.isin(kidney_background).mean()) # check, should be 1

    genelist_in_bg = genelist[genelist.isin(kidney_background)] # need just parts of cosmic that are in background
    len(genelist_in_bg)

    genelist_overlap.isin(kidney_background).mean() # should be 1


    import numpy as np
    genelist_not_kidney = genelist_in_bg[np.logical_not(genelist_in_bg.isin(kidney_features))]

    kidney_not_genelist = kidney_features[np.logical_not(kidney_features.isin(genelist_in_bg))]

    not_genelist_not_kidney = kidney_background[np.logical_not((kidney_background.isin(genelist_in_bg)) | (kidney_background.isin(kidney_features)))]


    contingency = pd.DataFrame({
                    'genelist': [len(genelist_overlap), len(genelist_not_kidney)], 
                    'not_genelist': [len(kidney_not_genelist), len(not_genelist_not_kidney)] 
                  })
    contingency.index = ['kidney', 'not_kidney']
    print(contingency)

    from scipy.stats import fisher_exact
    oddsr, p = fisher_exact(contingency, alternative='greater')
    print('Oddsr is ', oddsr, ' and p is ', p)

    return contingency, kidney_background, genelist_in_bg

contingency, kidney_background, genelist_in_bg = fishers(genelist, genelist_overlap, kidney_features)
# Out:
# Should be 1:  1.0
#             genelist  not_genelist
# kidney           147          4069
# not_kidney       496         17298
# Oddsr is  1.2599225854018186  and p is  0.00985775997962868

# %%
# check the contingency matrix
# checking contingency maths is right
def check_conting(contingency, genelist_in_bg, kidney_features, kidney_background):
    genelist_in_bg = genelist[genelist.isin(kidney_background)]
    assert len(genelist_in_bg) == contingency['genelist'].sum()

    assert len(kidney_features) == contingency.loc['kidney'].sum()

    assert len(kidney_background) == contingency.sum().sum()
    
check_conting(contingency, genelist_in_bg, kidney_features, kidney_background) # should not error

# %%
# running all gene lists through functions

genelist = read_genelist('Gene Lists - EpiFactor DB.csv')
kidney_features = read_in_kidney()
genelist_overlap = get_overlap(genelist, kidney_features)
contingency, kidney_background, genelist_in_bg = fishers(genelist, genelist_overlap, kidney_features)
check_conting(contingency, genelist_in_bg, kidney_features, kidney_background) # should not error
# Out:
# 720
# ['HDGFL2', 'A1CF', 'ACTB', 'ACTL6A', 'ACTL6B', 'ACTR3B', 'ACTR5', 'ACTR6', 'ACTR8', 'ADNP', 'AEBP2', 'AICDA', 'AIRE', 'ALKBH1', 'ANKRD32', 'ANP32A', 'ANP32B', 'ANP32E', 'APBB1', 'APEX1', 'APOBEC1', 'APOBEC2', 'APOBEC3A', 'APOBEC3B', 'APOBEC3C', 'APOBEC3D', 'APOBEC3F', 'APOBEC3G', 'APOBEC3H', 'ARID1A', 'ARID1B', 'ARID2', 'ARID4A', 'ARID4B', 'ARNTL', 'ARRB1', 'ASF1A', 'ASF1B', 'ASH1L', 'ASH2L', 'ASXL1', 'ASXL2', 'ASXL3', 'ATAD2', 'ATAD2B', 'ATF2', 'ATF7IP', 'ATM', 'ATN1', 'ATR', 'ATRX', 'ATXN7', 'ATXN7L3', 'AURKA', 'AURKB', 'AURKC', 'BABAM1', 'BAHD1', 'BANP', 'BAP1', 'BARD1', 'BAZ1A', 'BAZ1B', 'BAZ2A', 'BAZ2B', 'BCOR', 'BCORL1', 'BMI1', 'BPTF', 'BRCA1', 'BRCA2', 'BRCC3', 'BRD1', 'BRD2', 'BRD3', 'BRD4', 'BRD7', 'BRD8', 'BRD9', 'BRDT', 'BRE', 'BRMS1', 'BRMS1L', 'BRPF1', 'BRPF3', 'BRWD1', 'BRWD3', 'BUB1', 'C11ORF30', 'C14ORF169', 'C17ORF49', 'CARM1', 'CBX1', 'CBX2', 'CBX3', 'CBX4', 'CBX5', 'CBX6', 'CBX7', 'CBX8', 'CCDC101', 'CDC6', 'CDC73', 'CDK1', 'CDK17', 'CDK2', 'CDK3', 'CDK5', 'CDK7', 'CDK9', 'CDY1', 'CDY1B', 'CDY2A', 'CDY2B', 'CDYL', 'CDYL2', 'CECR2', 'CENPC', 'CHAF1A', 'CHAF1B', 'CHD1', 'CHD1L', 'CHD2', 'CHD3', 'CHD4', 'CHD5', 'CHD6', 'CHD7', 'CHD8', 'CHD9', 'CHEK1', 'CHRAC1', 'CHTOP', 'CHUK', 'CIR1', 'CIT', 'CLNS1A', 'CLOCK', 'CRB2', 'CREBBP', 'CSNK2A1', 'CSRP2BP', 'CTBP1', 'CTBP2', 'CTCF', 'CTCFL', 'CTR9', 'CUL1', 'CUL2', 'CUL3', 'CUL4A', 'CUL4B', 'CUL5', 'CXXC1', 'DAPK3', 'DAXX', 'DDB1', 'DDB2', 'DDX21', 'DDX50', 'DEK', 'DMAP1', 'DNAJC1', 'DNAJC2', 'DND1', 'DNMT1', 'DNMT3A', 'DNMT3B', 'DNMT3L', 'DNTTIP2', 'DOT1L', 'DPF1', 'DPF2', 'DPF3', 'DPPA3', 'DPY30', 'DR1', 'DTX3L', 'DZIP3', 'E2F6', 'EED', 'EHMT1', 'EHMT2', 'EID1', 'EID2', 'EID2B', 'ELP2', 'ELP3', 'ELP4', 'ELP5', 'ELP6', 'ENY2', 'EP300', 'EP400', 'EPC1', 'EPC2', 'ERBB4', 'ERCC6', 'EXOSC1', 'EXOSC2', 'EXOSC3', 'EXOSC4', 'EXOSC5', 'EXOSC6', 'EXOSC7', 'EXOSC8', 'EXOSC9', 'EYA1', 'EYA2', 'EYA3', 'EYA4', 'EZH1', 'EZH2', 'FAM175A', 'FAM175B', 'FBL', 'FBRS', 'FBRSL1', 'FOXA1', 'FOXO1', 'FOXP1', 'FOXP2', 'FOXP3', 'FOXP4', 'GADD45A', 'GADD45B', 'GADD45G', 'GATAD1', 'GATAD2A', 'GATAD2B', 'GFI1', 'GFI1B', 'GLYR1', 'GSE1', 'GSG2', 'GTF2I', 'GTF3C4', 'HAT1', 'HCFC1', 'HCFC2', 'HDAC1', 'HDAC10', 'HDAC11', 'HDAC2', 'HDAC3', 'HDAC4', 'HDAC5', 'HDAC6', 'HDAC7', 'HDAC8', 'HDAC9', 'HDGF', 'HELLS', 'HIF1AN', 'HINFP', 'HIRA', 'HIRIP3', 'HJURP', 'HLCS', 'HLTF', 'HMG20A', 'HMG20B', 'HMGB1', 'HMGN1', 'HMGN2', 'HMGN3', 'HMGN4', 'HMGN5', 'HP1BP3', 'HR', 'HSPA1A', 'HSPA1B', 'HUWE1', 'IKBKAP', 'IKZF1', 'IKZF3', 'ING1', 'ING2', 'ING3', 'ING4', 'ING5', 'INO80', 'INO80B', 'INO80C', 'INO80D', 'INO80E', 'JADE1', 'JADE2', 'JADE3', 'JAK2', 'JARID2', 'JDP2', 'JMJD1C', 'JMJD6', 'KANSL1', 'KANSL2', 'KANSL3', 'KAT2A', 'KAT2B', 'KAT5', 'KAT6A', 'KAT6B', 'KAT7', 'KAT8', 'KDM1A', 'KDM1B', 'KDM2A', 'KDM2B', 'KDM3A', 'KDM3B', 'KDM4A', 'KDM4B', 'KDM4C', 'KDM4D', 'KDM4E', 'KDM5A', 'KDM5B', 'KDM5C', 'KDM5D', 'KDM6A', 'KDM6B', 'KDM7A', 'KDM8', 'KEAP1', 'KMT2A', 'KMT2B', 'KMT2C', 'KMT2D', 'KMT2E', 'L3MBTL1', 'L3MBTL2', 'L3MBTL3', 'L3MBTL4', 'LAS1L', 'LBR', 'LEO1', 'LRWD1', 'MAP3K7', 'MAPKAPK3', 'MASTL', 'MAX', 'MAZ', 'MBD1', 'MBD2', 'MBD3', 'MBD4', 'MBD5', 'MBD6', 'MBIP', 'MBTD1', 'MCRS1', 'MDC1', 'MEAF6', 'MECP2', 'MEN1', 'MGA', 'MGEA5', 'MINA', 'MLLT1', 'MLLT10', 'MLLT6', 'MORF4L1', 'MORF4L2', 'MOV10', 'MPHOSPH8', 'MRGBP', 'MSH6', 'MSL1', 'MSL2', 'MSL3', 'MST1', 'MTA1', 'MTA2', 'MTA3', 'MTF2', 'MUM1', 'MYBBP1A', 'MYO1C', 'MYSM1', 'NAA60', 'NAP1L1', 'NAP1L2', 'NAP1L4', 'NASP', 'NAT10', 'NBN', 'NCL', 'NCOA1', 'NCOA2', 'NCOA3', 'NCOA6', 'NCOR1', 'NCOR2', 'NEK6', 'NEK9', 'NFRKB', 'NFYB', 'NFYC', 'NIPBL', 'NOC2L', 'NPAS2', 'NPM1', 'NPM2', 'NSD1', 'NSL1', 'OGT', 'PADI1', 'PADI2', 'PADI3', 'PADI4', 'PAF1', 'PAGR1', 'PAK2', 'PARG', 'PARP1', 'PARP2', 'PARP3', 'PAXIP1', 'PBK', 'PBRM1', 'PCGF1', 'PCGF2', 'PCGF3', 'PCGF5', 'PCGF6', 'PCNA', 'PDP1', 'PELP1', 'PHC1', 'PHC2', 'PHC3', 'PHF1', 'PHF10', 'PHF12', 'PHF13', 'PHF14', 'PHF19', 'PHF2', 'PHF20', 'PHF20L1', 'PHF21A', 'PHF8', 'PHIP', 'PIWIL4', 'PKM', 'PKN1', 'POGZ', 'POLE3', ...
# 2        ACTB
# 9        ADNP
# 11      AICDA
# 15     ANP32A
# 17     ANP32E
#         ...
# 710    ZNF217
# 711    ZNF516
# 712    ZNF532
# 715    ZNF687
# 718    ZRANB3
# Name: HGNC_symbol, Length: 147, dtype: object
# 147
# 0.20416666666666666
# 0.03486717267552182
# Should be 1:  1.0
#             genelist  not_genelist
# kidney           147          4069
# not_kidney       496         17298
# Oddsr is  1.2599225854018186  and p is  0.00985775997962868

# %%
genelist = read_genelist('Gene Lists - KEGG_hsa05211_RCC.csv')
kidney_features = read_in_kidney()
genelist_overlap = get_overlap(genelist, kidney_features)
contingency, kidney_background, genelist_in_bg = fishers(genelist, genelist_overlap, kidney_features)
check_conting(contingency, genelist_in_bg, kidney_features, kidney_background) # should not error
# no significance with RCC KEGG pathway
# Out:
# 69
# ['AKT1', 'AKT2', 'AKT3', 'ARAF', 'ARNT', 'ARNT2', 'BAD', 'BRAF', 'BUB1B-PAK6', 'CDC42', 'CDKN1A', 'CREBBP', 'CRK', 'CRKL', 'CUL2', 'EGLN1', 'EGLN2', 'EGLN3', 'ELOB', 'ELOC', 'EP300', 'EPAS1', 'ETS1', 'FH', 'FLCN', 'GAB1', 'GRB2', 'HGF', 'HIF1A', 'HRAS', 'JUN', 'KRAS', 'MAP2K1', 'MAP2K2', 'MAPK1', 'MAPK3', 'MET', 'NRAS', 'PAK1', 'PAK2', 'PAK3', 'PAK4', 'PAK5', 'PAK6', 'PDGFB', 'PIK3CA', 'PIK3CB', 'PIK3CD', 'PIK3R1', 'PIK3R2', 'PIK3R3', 'PRCC', 'PTPN11', 'RAC1', 'RAF1', 'RAP1A', 'RAP1B', 'RAPGEF1', 'RBX1', 'SLC2A1', 'SOS1', 'SOS2', 'TFE3', 'TGFA', 'TGFB1', 'TGFB2', 'TGFB3', 'VEGFA', 'VHL']
# 6        BAD
# 9      CDC42
# 11    CREBBP
# 21     EPAS1
# 22      ETS1
# 26      GRB2
# 29      HRAS
# 30       JUN
# 36       MET
# 38      PAK1
# 41      PAK4
# 47    PIK3CD
# 49    PIK3R2
# 50    PIK3R3
# 52    PTPN11
# 64     TGFB1
# 65     TGFB2
# Name: 0, dtype: object
# 17
# 0.2463768115942029
# 0.004032258064516129
# Should be 1:  1.0
#             genelist  not_genelist
# kidney            17          4199
# not_kidney        49         17745
# Oddsr is  1.4661654135338347  and p is  0.11559247243935564

# %%
genelist = read_genelist('Gene Lists - pRCC -harmonizome -Diseases db.csv')
kidney_features = read_in_kidney()
genelist_overlap = get_overlap(genelist, kidney_features)
contingency, kidney_background, genelist_in_bg = fishers(genelist, genelist_overlap, kidney_features)
check_conting(contingency, genelist_in_bg, kidney_features, kidney_background) # should not error
# Out:
# 81
# ['AMACR', 'PRCC', 'KRT7', 'TFE3', 'FH', 'SCHIP1', 'MET', 'FBXO47', 'CA9', 'CDH16', 'LYPD1', 'PAX8', 'TCEB3', 'FLCN', 'MAD2L2', 'WT1', 'NAPSA', 'PTEN', 'TFEB', 'ASPSCR1', 'BAMBI', 'VIM', 'TFEC', 'B3GAT1', 'NONO', 'PAX2', 'HGF', 'CDC73', 'VHL', 'C1ORF174', 'STK10', 'CLEC2A', 'CPM', 'SLC34A2', 'MUC1', 'PLIN2', 'CDH1', 'RASSF1', 'ACAT1', 'KEAP1', 'S100A1', 'PDPN', 'SEPT2', 'VCL', 'NNMT', 'ELF3', 'ZNF135', 'EGLN2', 'HIF1A', 'CUL3', 'CLDN7', 'AKR1B10', 'SLC2A1', 'BRAF', 'SEPT5', 'PVALB', 'ZNF77', 'KRT20', 'SRMS', 'CDR2', 'KRT8', 'PGR', 'UBE2S', 'MIR210', 'CXCL16', 'FUT4', 'FBXW7', 'AQP3', 'RBPJ', 'MN1', 'HAVCR1', 'RET', 'CD82', 'CALCA', 'AQP1', 'HBA1', 'MMP11', 'TP53', 'IL2', 'HBA2', 'NCAM1']
# 0       AMACR
# 6         MET
# 16      NAPSA
# 19    ASPSCR1
# 23     B3GAT1
# 25       PAX2
# 30      STK10
# 37     RASSF1
# 38      ACAT1
# 40     S100A1
# 45       ELF3
# 50      CLDN7
# 60       KRT8
# 61        PGR
# 62      UBE2S
# 64     CXCL16
# 69        MN1
# 74       AQP1
# 77       TP53
# Name: Symbol, dtype: object
# 19
# 0.2345679012345679
# 0.004506641366223909
# Should be 1:  1.0
#             genelist  not_genelist
# kidney            19          4197
# not_kidney        55         17739
# Oddsr is  1.460094872961206  and p is  0.10300780961930461

# %%
genelist = read_genelist('Gene Lists - RCC harmonizome -diseases db.csv')
kidney_features = read_in_kidney()
genelist_overlap = get_overlap(genelist, kidney_features)
contingency, kidney_background, genelist_in_bg = fishers(genelist, genelist_overlap, kidney_features)
check_conting(contingency, genelist_in_bg, kidney_features, kidney_background) # should not error
# Out:
# 829
# ['IL2', 'VHL', 'MTOR', 'TFE3', 'CA9', 'IFNA1', 'PRCC', 'FLCN', 'FH', 'KRT7', 'ZNF135', 'DIRC2', 'VEGFA', 'PDPN', 'HIF1A', 'AMACR', 'SRMS', 'CDH6', 'TFEB', 'PBRM1', 'IFNA2', 'PAX8', 'CDH16', 'PAX2', 'TP53', 'MET', 'TSC2', 'TCEB1', 'CUL2', 'TCEB2', 'TPX2', 'EPAS1', 'SETD2', 'CD4', 'CDH1', 'AKT1', 'FLT1', 'EGFR', 'CD34', 'CRP', 'CSF2', 'CD70', 'NCAM1', 'PTEN', 'TPBG', 'MLANA', 'FHIT', 'PCNA', 'IL6', 'ASPSCR1', 'CCND1', 'FGF2', 'HLA-A', 'ABCB1', 'RBX1', 'CD6', 'KRT20', 'S100A1', 'HLA-B', 'TNFSF10', 'RNF139', 'B3GAT1', 'SMUG1', 'ALPP', 'ARPP21', 'ALPPL2', 'ALPL', 'MMP2', 'TNF', 'KDR', 'CLDN8', 'IFNA10', 'EGLN3', 'IL21', 'SDHB', 'PDGFRB', 'HBA1', 'WT1', 'MITF', 'HLA-C', 'PVALB', 'MIR210', 'HBA2', 'KDM5C', 'PARK2', 'TYMP', 'BIRC5', 'RASSF1', 'PTHLH', 'MMP9', 'CA12', 'SLC2A1', 'ZHX2', 'CD44', 'NNMT', 'COL18A1', 'PLIN2', 'SCHIP1', 'IFNA21', 'TGFB1', 'ENO2', 'IL4', 'KANK1', 'HAVCR1', 'ERBB2', 'JADE1', 'IFNA17', 'MUC1', 'LRCH4', 'FLT3', 'CD80', 'CTLA4', 'CD83', 'BAP1', 'SPAG4', 'B2M', 'FASLG', 'SDHC', 'STAT3', 'CD68', 'LRRC2', 'FOXP3', 'KANK4', 'EIF4EBP1', 'CASP3', 'MAGEA9', 'MAGEA9B', 'SRC', 'ICAM1', 'SYP', 'CALB2', 'FN1', 'KDM6A', 'SYCN', 'NKX2-1', 'MAGEA6', 'MIR21', 'TSC1', 'TG', 'GJB1', 'ANXA2', 'ABHD14A', 'BAX', 'AQP1', 'NAPSA', 'HIVEP3', 'ROS1', 'KRT8', 'MKI67', 'SFRP1', 'VCL', 'SDHD', 'CXCL12', 'RET', 'PTPRG', 'CDH2', 'NONO', 'SPINT2', 'LLGL1', 'HLA-G', 'ZNF77', 'CHGA', 'CDKN1A', 'CLTC', 'MSLN', 'TAP1', 'MT1G', 'SMARCB1', 'SDHA', 'TFCP2L1', 'PITX1', 'NDRG2', 'HGF', 'EGLN2', 'CLDN7', 'HEPACAM', 'CORO6', 'KANK3', 'ZNF600', 'AMMECR1L', 'ACOT6', 'TMEM213', 'INO80D', 'MDM2', 'SIGLEC7', 'FBXO47', 'POLR2A', 'C4ORF46', 'LCK', 'PDGFRA', 'ALB', 'RNF112', 'LRRC3B', 'GSTA3', 'GSTA2', 'GSTA4', 'PKM', 'PRAME', 'PTGS2', 'FABP7', 'GSTA1', 'TGFBR2', 'TCF21', 'CDCP1', 'EZH2', 'FUT4', 'CAV1', 'ALK', 'GSTP1', 'CASP8', 'CXCR4', 'UPK3A', 'RCC2', 'SLC17A5', 'DDX23', 'FER', 'VIM', 'RPLP0', 'KISS1', 'F8', 'CTSK', 'GNG4', 'ZFP3', 'CXCR3', 'CD86', 'TMSB4XP8', 'IL1B', 'ABCG2', 'AFP', 'IFNAR2', 'CASP9', 'FTL', 'CDKN1B', 'ANXA4', 'HDAC9', 'MGP', 'KRT5', 'VBP1', 'VEGFC', 'BCL2', 'TCEB3', 'HNF4A', 'KLF8', 'FNIP1', 'SECTM1', 'LAP3', 'IL2RA', 'KIT', 'CD69', 'FGF1', 'TRAF3', 'DLL4', 'EFHD1', 'FOLH1', 'HIF1AN', 'DNTT', 'FTH1', 'CCNB1', 'IL36RN', 'KANK2', 'LIMCH1', 'ATP6V1G3', 'KRT34', 'RALYL', 'LMAN2', 'BSG', 'RGS5', 'IGFBP3', 'HRAS', 'FAM107A', 'HIST2H3PS2', 'FADS1', 'PLAU', 'H3F3B', 'H3F3A', 'KISS1R', 'REN', 'PTH', 'FZR1', 'DKK3', 'HNF1B', 'KAAG1', 'RNF185', 'GAL3ST1', 'ANPEP', 'CDKN2A', 'SKP2', 'KLHL35', 'TIMP1', 'INHA', 'PRF1', 'CXXC4', 'LGALS3', 'RPS6KB1', 'MIR10B', 'ITPR2', 'SMARCA2', 'STC2', 'ZNF419', 'MMP7', 'SPP1', 'BNIP3', 'STAT1', 'IFNB1', 'CXCL9', 'LGALS1', 'KHK', 'PGR', 'CD82', 'GGT1', 'CMTM8', 'L1CAM', 'BCL2L1', 'GSN', 'EN2', 'THRB', 'TNS1', 'SEMA5B', 'TMC5', 'JUN', 'IGF1', 'TNS3', 'FLT4', 'FUT11', 'UBE2QL1', 'TIMP2', 'EPOR', 'TTYH2', 'CXCL8', 'STK10', 'TXLNA', 'PTGER4', 'IGF1R', 'LUC7L3', 'TMED6', 'TYMS', 'PTER', 'SSH3', 'APAF1', 'IFNA8', 'GATA3', 'RELA', 'RAP1GAP', 'ZNF773', 'ITGAM', 'ACTL8', 'RHEBL1', 'RPS9', 'UQCR11', 'ELAVL1', 'KRT19', 'EPHA2', 'VASH1', 'NOTCH1', 'ZNF410', 'PNCK', 'AXL', 'ARID1A', 'SETD3', 'GSTM1', 'SLC35G2', 'DNAJB8', 'PPIA', 'CXCL10', 'DUSP9', 'ESR1', 'ABCC3', 'ANKRD11', 'CACNG7', 'MAD2L2', 'ORAI3', 'NCR1', 'MIB1', 'ZNRD1', 'CCDC8', 'IL7', 'NKX1-1', 'PSMB11', 'NKIRAS1', 'NDUFS7', 'CDK2', 'ANTXR1', 'DKK2', 'MIR145', 'TMEM74', 'LDHA', 'CD40', 'LOX', 'KLK3', 'NUP54', 'IL26', 'SSH2', 'SLFN5', 'GATA5', 'SPINK7', 'PXN', 'IL13', 'RPTOR', 'CCND3', 'FGFR1', 'THBS1', 'GSTT1', 'GSTTP1', 'ETNPPL', 'LRIG1', 'BPHL', 'CD247', 'DNMT1', 'TRIM8', 'KMT2B', 'GBP4', 'ZSCAN18', 'FSCN1', 'LAMA4', 'ANGPT2', 'LATS1', 'C11ORF54', 'PARD3', 'ANXA5', 'CDH11', 'PMEL', 'FGF5', 'TRIM9', 'TOP1', 'ORC2', 'SYNGR3', 'EBNA1BP2', 'VDR', 'TBC1D8', 'RARB', 'FUBP3', 'ESM1', 'CRABP2', 'FAM92A1', 'JAK3', 'JAK1', 'TERT', 'CUL1', 'CXCL5', 'CD27', 'IGF2', 'TEAD3', 'MICA', 'MSL2', 'ZEB2', 'CYP1A1', 'CSF1R', 'ACTG1', 'PCDH8', 'CMTM3', 'ZNF346', 'LEFTY1', 'ANGPT1', 'MAL2', 'CX ...
# 2        MTOR
# 15      AMACR
# 17       CDH6
# 23       PAX2
# 24       TP53
#         ...
# 822      MUC6
# 823    TFAP2A
# 825     STK11
# 826      IRF1
# 828    CLCNKB
# Name: symbol, Length: 193, dtype: object
# 193
# 0.23281061519903498
# 0.04577798861480076
# Should be 1:  1.0
#             genelist  not_genelist
# kidney           193          4023
# not_kidney       535         17259
# Oddsr is  1.5476370681664542  and p is  5.093734462597253e-07
